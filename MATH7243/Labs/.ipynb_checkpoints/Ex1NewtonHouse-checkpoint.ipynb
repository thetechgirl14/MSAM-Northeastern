# %% [markdown]
# ## Exploring Data
#
# ### The Data is the house prices sold in Newton 2020 Dec, downloaded from www.Redfin.com

# %%
import numpy as np
import pandas as pd

# To plot pretty figures
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt
import pylab

mpl.rc('axes', labelsize=12)
mpl.rc('xtick', labelsize=10)
mpl.rc('ytick', labelsize=10)

# %%
Newton=pd.read_csv("redfin_Newton2020Dec.csv", error_bad_lines=False) 

#Newton.tail()
Newton.head(10) 
#Newton
# Out:
#    SALE_TYPE         SOLD_DATE              PROPERTY_TYPE             ADDRESS  \
# 0  PAST SALE   December-4-2020  Single Family Residential     95 Peregrine Rd
# 1  PAST SALE  November-24-2020  Single Family Residential   503 California St
# 2  PAST SALE   December-4-2020  Single Family Residential  6 Valley Spring Rd
# 3  PAST SALE  December-17-2020  Single Family Residential       650 Centre St
# 4  PAST SALE  December-21-2020  Single Family Residential   19 Gray Birch Ter
# 5  PAST SALE  December-17-2020  Single Family Residential     50 Jefferson St
# 6  PAST SALE   December-2-2020  Single Family Residential      100 Gardner St
# 7  PAST SALE  November-24-2020  Single Family Residential     23 Marcellus Dr
# 8  PAST SALE  November-25-2020  Single Family Residential     101 Falmouth Rd
# 9  PAST SALE  November-25-2020  Single Family Residential        114 Derby St
#
#      CITY STATE_OR_PROVINCE  ZIP_OR_POSTAL_CODE    PRICE  BEDS  BATHS  ...  \
# 0  Newton                MA                2459  1090000     3    3.0  ...
# 1  Newton                MA                2460   805000     3    2.5  ...
# 2  Newton                MA                2458   905000     4    2.5  ...
# 3  Newton                MA                2458  2660000     7    4.5  ...
# 4  Newton                MA                2460  1925000     4    4.0  ...
# 5  Newton                MA                2458   965000     4    2.5  ...
# 6  Newton                MA                2458   775000     2    1.5  ...
# 7  Newton                MA                2459  1250000     3    2.5  ...
# 8  Newton                MA                2465   815000     2    2.0  ...
# 9  Newton                MA                2465   900000     6    3.0  ...
#
#   STATUS  NEXT OPEN HOUSE START TIME  NEXT OPEN HOUSE END TIME  \
# 0   Sold                         NaN                       NaN
# 1   Sold                         NaN                       NaN
# 2   Sold                         NaN                       NaN
# 3   Sold                         NaN                       NaN
# 4   Sold                         NaN                       NaN
# 5   Sold                         NaN                       NaN
# 6   Sold                         NaN                       NaN
# 7   Sold                         NaN                       NaN
# 8   Sold                         NaN                       NaN
# 9   Sold                         NaN                       NaN
#
#    URL (SEE http://www.redfin.com/buy-a-home/comparative-market-analysis FOR INFO ON PRICING)  \
# 0  http://www.redfin.com/MA/Newton/95-Peregrine-R...
# 1  http://www.redfin.com/MA/Newton/503-California...
# 2  http://www.redfin.com/MA/Newton/6-Valley-Sprin...
# 3  http://www.redfin.com/MA/Newton/650-Centre-St-...
# 4  http://www.redfin.com/MA/Newton/19-Gray-Birch-...
# 5  http://www.redfin.com/MA/Newton/50-Jefferson-S...
# 6  http://www.redfin.com/MA/Newton/100-Gardner-St...
# 7  http://www.redfin.com/MA/Newton/23-Marcellus-D...
# 8  http://www.redfin.com/MA/Newton/101-Falmouth-R...
# 9  http://www.redfin.com/MA/Newton/114-Derby-St-0...
#
#     SOURCE      MLS#  FAVORITE INTERESTED   LATITUDE  LONGITUDE
# 0  MLS PIN  72723436         N          Y  42.295733 -71.177180
# 1  MLS PIN  72721482         N          Y  42.362241 -71.208741
# 2  MLS PIN  72734897         N          Y  42.345765 -71.175741
# 3  MLS PIN  72623790         N          Y  42.348963 -71.187043
# 4  MLS PIN  72752876         N          Y  42.349326 -71.212082
# 5  MLS PIN  72692798         N          Y  42.358481 -71.183492
# 6  MLS PIN  72738992         N          Y  42.359823 -71.193378
# 7  MLS PIN  72706173         N          Y  42.310399 -71.198344
# 8  MLS PIN  72739912         N          Y  42.360672 -71.230181
# 9  MLS PIN  72747359         N          Y  42.357626 -71.228418
#
# [10 rows x 27 columns]

# %% [markdown]
# ### Exploring Datasets:
#
# After reading the high level description, we are ready to dig into the dataset itself. Just displaying the data gave us some information: A brief look at  the content of the columns along with a description of the size, 1460 rows × 81 columns.
#
# There are a few commands particularly useful for first pass data analysis:
#
# * `type(x)` returns the data type of a variable `x`. In this case we know `Newton` is a dataframe but this may not always be so clear.
# * `DataFrame.head(n)` a data frame has quite a few built in functions associated with it. The head function returns the first `n` columns of the data frame. To use the head function to display the first 5 rows we use `Newton.head(5)`.
# * `DataFrame.tail(n)` displays the last `n` columns of the dataframe.
# * `DataFrame.shape` is a varaible defining the dimensions of the dataset. You can retrieve them, or change them by changing this variable.
#
# Lets try these out below

# %%
display(type(Newton))
display(Newton.head(5))
display(Newton.tail(5))
print("Our datasets has dimensions", Newton.shape)
#print("Our datasets has dimensions", Newton.shape[0], "by", Newton.shape[1])
# Out:
# pandas.core.frame.DataFrame
#    SALE_TYPE         SOLD_DATE              PROPERTY_TYPE             ADDRESS  \
# 0  PAST SALE   December-4-2020  Single Family Residential     95 Peregrine Rd
# 1  PAST SALE  November-24-2020  Single Family Residential   503 California St
# 2  PAST SALE   December-4-2020  Single Family Residential  6 Valley Spring Rd
# 3  PAST SALE  December-17-2020  Single Family Residential       650 Centre St
# 4  PAST SALE  December-21-2020  Single Family Residential   19 Gray Birch Ter
#
#      CITY STATE_OR_PROVINCE  ZIP_OR_POSTAL_CODE    PRICE  BEDS  BATHS  ...  \
# 0  Newton                MA                2459  1090000     3    3.0  ...
# 1  Newton                MA                2460   805000     3    2.5  ...
# 2  Newton                MA                2458   905000     4    2.5  ...
# 3  Newton                MA                2458  2660000     7    4.5  ...
# 4  Newton                MA                2460  1925000     4    4.0  ...
#
#   STATUS  NEXT OPEN HOUSE START TIME  NEXT OPEN HOUSE END TIME  \
# 0   Sold                         NaN                       NaN
# 1   Sold                         NaN                       NaN
# 2   Sold                         NaN                       NaN
# 3   Sold                         NaN                       NaN
# 4   Sold                         NaN                       NaN
#
#    URL (SEE http://www.redfin.com/buy-a-home/comparative-market-analysis FOR INFO ON PRICING)  \
# 0  http://www.redfin.com/MA/Newton/95-Peregrine-R...
# 1  http://www.redfin.com/MA/Newton/503-California...
# 2  http://www.redfin.com/MA/Newton/6-Valley-Sprin...
# 3  http://www.redfin.com/MA/Newton/650-Centre-St-...
# 4  http://www.redfin.com/MA/Newton/19-Gray-Birch-...
#
#     SOURCE      MLS#  FAVORITE INTERESTED   LATITUDE  LONGITUDE
# 0  MLS PIN  72723436         N          Y  42.295733 -71.177180
# 1  MLS PIN  72721482         N          Y  42.362241 -71.208741
# 2  MLS PIN  72734897         N          Y  42.345765 -71.175741
# 3  MLS PIN  72623790         N          Y  42.348963 -71.187043
# 4  MLS PIN  72752876         N          Y  42.349326 -71.212082
#
# [5 rows x 27 columns]
#     SALE_TYPE         SOLD_DATE              PROPERTY_TYPE  \
# 54  PAST SALE  December-22-2020  Single Family Residential
# 55  PAST SALE  December-15-2020  Single Family Residential
# 56  PAST SALE   December-2-2020  Single Family Residential
# 57  PAST SALE  December-18-2020  Single Family Residential
# 58  PAST SALE   December-3-2020  Single Family Residential
#
#                  ADDRESS    CITY STATE_OR_PROVINCE  ZIP_OR_POSTAL_CODE  \
# 54      203 Greenwood St  Newton                MA                2459
# 55        45 Village Cir  Newton                MA                2459
# 56  542 Commonwealth Ave  Newton                MA                2459
# 57       30 Columbine Rd  Newton                MA                2459
# 58  700 Commonwealth Ave  Newton                MA                2459
#
#       PRICE  BEDS  BATHS  ... STATUS  NEXT OPEN HOUSE START TIME  \
# 54  1595000     4    2.5  ...   Sold                         NaN
# 55  2250000     7    8.5  ...   Sold                         NaN
# 56  1180000     4    3.0  ...   Sold                         NaN
# 57  3300000     5    6.5  ...   Sold                         NaN
# 58  2300000     5    3.5  ...   Sold                         NaN
#
#     NEXT OPEN HOUSE END TIME  \
# 54                       NaN
# 55                       NaN
# 56                       NaN
# 57                       NaN
# 58                       NaN
#
#     URL (SEE http://www.redfin.com/buy-a-home/comparative-market-analysis FOR INFO ON PRICING)  \
# 54  http://www.redfin.com/MA/Newton/203-Greenwood-...
# 55  http://www.redfin.com/MA/Newton/45-Village-Cir...
# 56  http://www.redfin.com/MA/Newton/542-Commonweal...
# 57  http://www.redfin.com/MA/Newton/30-Columbine-R...
# 58  http://www.redfin.com/MA/Newton-Centre/700-Com...
#
#      SOURCE      MLS#  FAVORITE INTERESTED   LATITUDE  LONGITUDE
# 54  MLS PIN  72732306         N          Y  42.306599 -71.188644
# 55  MLS PIN  72723390         N          Y  42.306781 -71.189062
# 56  MLS PIN  72718615         N          Y  42.336024 -71.188830
# 57  MLS PIN  72717718         N          Y  42.299323 -71.177853
# 58  MLS PIN  72727864         N          Y  42.336067 -71.195746
#
# [5 rows x 27 columns]
# Our datasets has dimensions (59, 27)

# %% [markdown]
# Looking at the output, we make a couple of immediate observations
#
# * Jupyter isn't displaying all 81 of the columns. This is okay, we can get information about them later but it's good to note.
# * We have a large mixture of variable types, some numerical (__Lotarea__) some categorical (__MSZoning__) and others that could be either (__MSSubClass__). You can always check the documentation.
# * The value `NaN` standing for "not a number" keeps appearing. This usually means there's no information about that feature of that particular property. We will have to deal with `NaN` values later.
#
# We can actually get some information about the data type of each feature and how many values are `NaN` by using the `DataFrame.info()` function. We can also at least get a list of column names using `list(Newton)`.

# %%
names = list(Newton)
print(names)
# Out:
# ['SALE_TYPE', 'SOLD_DATE', 'PROPERTY_TYPE', 'ADDRESS', 'CITY', 'STATE_OR_PROVINCE', 'ZIP_OR_POSTAL_CODE', 'PRICE', 'BEDS', 'BATHS', 'LOCATION', 'SQUARE_FEET', 'LOT_SIZE', 'YEAR_BUILT', 'DAYS_ON_MARKET', 'Per_SQUARE_FEET', 'HOA_MONTH', 'STATUS', 'NEXT OPEN HOUSE START TIME', 'NEXT OPEN HOUSE END TIME', 'URL (SEE http://www.redfin.com/buy-a-home/comparative-market-analysis FOR INFO ON PRICING)', 'SOURCE', 'MLS#', 'FAVORITE', 'INTERESTED', 'LATITUDE', 'LONGITUDE']

# %%
Newton.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59 entries, 0 to 58
# Data columns (total 27 columns):
#  #   Column                                                                                      Non-Null Count  Dtype
# ---  ------                                                                                      --------------  -----
#  0   SALE_TYPE                                                                                   59 non-null     object
#  1   SOLD_DATE                                                                                   59 non-null     object
#  2   PROPERTY_TYPE                                                                               59 non-null     object
#  3   ADDRESS                                                                                     59 non-null     object
#  4   CITY                                                                                        59 non-null     object
#  5   STATE_OR_PROVINCE                                                                           59 non-null     object
#  6   ZIP_OR_POSTAL_CODE                                                                          59 non-null     int64
#  7   PRICE                                                                                       59 non-null     int64
#  8   BEDS                                                                                        59 non-null     int64
#  9   BATHS                                                                                       59 non-null     float64
#  10  LOCATION                                                                                    59 non-null     object
#  11  SQUARE_FEET                                                                                 59 non-null     int64
#  12  LOT_SIZE                                                                                    59 non-null     int64
#  13  YEAR_BUILT                                                                                  59 non-null     int64
#  14  DAYS_ON_MARKET                                                                              59 non-null     int64
#  15  Per_SQUARE_FEET                                                                             59 non-null     int64
#  16  HOA_MONTH                                                                                   0 non-null      float64
#  17  STATUS                                                                                      59 non-null     object
#  18  NEXT OPEN HOUSE START TIME                                                                  0 non-null      float64
#  19  NEXT OPEN HOUSE END TIME                                                                    0 non-null      float64
#  20  URL (SEE http://www.redfin.com/buy-a-home/comparative-market-analysis FOR INFO ON PRICING)  59 non-null     object
#  21  SOURCE                                                                                      59 non-null     object
#  22  MLS#                                                                                        59 non-null     int64
#  23  FAVORITE                                                                                    59 non-null     object
#  24  INTERESTED                                                                                  59 non-null     object
#  25  LATITUDE                                                                                    59 non-null     float64
#  26  LONGITUDE                                                                                   59 non-null     float64
# dtypes: float64(6), int64(9), object(12)
# memory usage: 12.6+ KB

# %%
Newton["ZIP_OR_POSTAL_CODE"].value_counts()
# Out:
# 2459    16
# 2465    12
# 2460    10
# 2458     6
# 2466     5
# 2461     4
# 2468     4
# 2464     1
# 2467     1
# Name: ZIP_OR_POSTAL_CODE, dtype: int64

# %%
Newton.describe()
# Out:
#        ZIP_OR_POSTAL_CODE         PRICE       BEDS      BATHS  SQUARE_FEET  \
# count           59.000000  5.900000e+01  59.000000  59.000000    59.000000
# mean          2461.847458  1.611530e+06   4.338983   3.355932  3413.016949
# std              3.331219  8.099258e+05   1.334039   1.564837  1683.941953
# min           2458.000000  6.300000e+05   2.000000   1.500000   840.000000
# 25%           2459.000000  9.425000e+05   3.000000   2.500000  1908.500000
# 50%           2460.000000  1.336000e+06   4.000000   3.000000  3149.000000
# 75%           2465.000000  1.905000e+06   5.000000   4.000000  4485.500000
# max           2468.000000  3.550000e+06   8.000000   8.500000  8206.000000
#
#            LOT_SIZE   YEAR_BUILT  DAYS_ON_MARKET  Per_SQUARE_FEET  HOA_MONTH  \
# count     59.000000    59.000000       59.000000        59.000000        0.0
# mean   13942.186441  1930.677966       14.389831       486.830508        NaN
# std    12133.238494    47.221576        8.366635       100.169021        NaN
# min     3966.000000  1830.000000        1.000000       286.000000        NaN
# 25%     7410.500000  1898.500000        6.000000       425.500000        NaN
# 50%    10160.000000  1927.000000       15.000000       489.000000        NaN
# 75%    15354.500000  1953.000000       21.000000       551.500000        NaN
# max    85421.000000  2020.000000       29.000000       750.000000        NaN
#
#        NEXT OPEN HOUSE START TIME  NEXT OPEN HOUSE END TIME          MLS#  \
# count                         0.0                       0.0  5.900000e+01
# mean                          NaN                       NaN  7.272093e+07
# std                           NaN                       NaN  3.318441e+04
# min                           NaN                       NaN  7.254849e+07
# 25%                           NaN                       NaN  7.271817e+07
# 50%                           NaN                       NaN  7.273021e+07
# 75%                           NaN                       NaN  7.273853e+07
# max                           NaN                       NaN  7.275288e+07
#
#         LATITUDE  LONGITUDE
# count  59.000000  59.000000
# mean   42.335913 -71.208076
# std     0.019683   0.019941
# min    42.290418 -71.253431
# 25%    42.322245 -71.220366
# 50%    42.342506 -71.207766
# 75%    42.349318 -71.193286
# max    42.363298 -71.175161

# %% [markdown]
# We can immediately read off which columns are numbers and which are other objects. All of this will help us in deciding on which variables its meaningful to use regression to predict the housing price.
#
# We also see that __PoolQC__, __Fence__, __MiscFeature__ all contain a very small number of non-null objects. A non-null object is any value that isn't `NaN`, so this is saying that we mostly don't have data about __PoolQC__, __Fence__, __MiscFeature__.
#
# <div class="alert alert-block alert-warning">
# <b>Stats Corner:</b> Be warned, being a number does not mean the feature should be treated as numeric. Remember that there are 4 main variable types in statistics:
# <ul><li><b>Discrete:</b> varaibles that take a finite number of values with no relation between the values. For example, type of fruit.</li>
#     <li><b>Ordinal:</b> variables whose values for a set with a well ordering. For example, stars on a yelp review. 3 is better than 2 but there is no other quantifiable evaluation we can make.
#     <li><b>Interval:</b> continuous variables without a fixed, meaningful 0. For example, temperature in $^\circ C$ can take a continuous value, but $2^\circ C$ isn't twice as hot as $1^\circ C$.
#     <li><b>Ratio:</b> continuous variables with a fixed, meaningful 0.
# </ul>
# Regression might not make sense on discrete variables, and must be more carefully interpreted for ordinal variables. We can however perform regression on binary discrete variables since different choices of order would lead to linear functions differing only by a sign.
# </div>
#
# Finally, lets get some idea of what the target range is. The variable we will try to fit is __SalePrice__ so lets use matplotlib to get an idea of what the data looks like.

# %% [markdown]
# #### Plotting Data
#
# We will use `matplotlib` to do most of our plotting. There are some more advanced libraries for producing more complicated graphics objects like maps and network graphs but we will only bring those in when needed.
#
# We will start my importing `pyplot` from the `matplotlib` library and using the `hist` function to display a histogram of the sale price data.

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
Newton.hist(bins=50, figsize=(40,30))
#save_fig("attribute_histogram_plots")
plt.show()

# %%
from matplotlib import pyplot as plt
fig, ax = plt.subplots()

ax.hist(Newton.PRICE,bins=5, rwidth=.8)
plt.show()

# %% [markdown]
# Here, the axis `ax` refers to the specific picture while `fig` refers to an invisible container around it that may contain many pictures inside it.
#
# This is a good start, but we should always try to make our plots meaning but adding annotation. In this case, lets give the plot a title, label the axes and increase the size of the figure a bit.
#
# * `ax.xlabel("X Label")` sets the x axis label for the picture. We can set the fontsize by including `fontsize=`.
# * `ax.ylabel("Y Label")` sets the y axis label for the picture.
# * `ax.set_title("Title")` sets the title for the picture.
# * `fig.set_size_inches(10, 7)` sets the dimensions of the image

# %%
fig, ax = plt.subplots()

ax.hist(Newton.PRICE,bins=55, rwidth=.8)
ax.set_xlabel("Housing Price", fontsize=20)
ax.set_ylabel("Count", fontsize=20)
ax.set_title("How much do houses cost?", fontsize=20)
fig.set_size_inches(10, 7)
plt.show()

# %% [markdown]
# Let get the minimum, maximum and average housing cost.

# %%
print("Minimum Housing Cost:", min(Newton.PRICE))
print("Minimum Housing Cost:", max(Newton.PRICE))
print("Minimum Housing Cost:", np.mean(Newton.PRICE))
# Out:
# Minimum Housing Cost: 630000
# Minimum Housing Cost: 3550000
# Minimum Housing Cost: 1611529.6779661018

# %% [markdown]
# Lets explore some of the other variables, lets take a look at lot size:

# %%
fig, ax = plt.subplots()

NewtonLot=Newton.LOT_SIZE
ax.hist(NewtonLot, bins=75, rwidth=.8)
ax.set_xlabel("Lot Size", fontsize=20)
ax.set_ylabel("Count", fontsize=20)
ax.set_title("How big are the lots?", fontsize=20)
fig.set_size_inches(10, 7)
plt.show()

# %% [markdown]
# Notice that there are a couple of lots that are so extreme that they're not giving us a very good look at the center. Lets cut out all the value above 50,000 sq ft and plot again. We define a logical index `z=Newtonlot<50000`, which is just a vector of true and false values. If we put this index into a array of the same size, it will only return that values for which the index `z` is true:

# %%
fig, ax = plt.subplots()

z = NewtonLot<50000

ax.hist(NewtonLot[z],bins=75, rwidth=.8)
ax.set_xlabel("Lot Size", fontsize=20)
ax.set_ylabel("Count", fontsize=20)
ax.set_title("How big are the lots?", fontsize=20)
fig.set_size_inches(10, 7)
plt.show()

# %% [markdown]
# ## Scatter Plots for Numerical Features
#
# In this lab, we really want to look at the numerical features, and in fact only the ordinal features. To pull out the values we will use another built in function of dataframes, the `select_dtype` function:
#
# * `DataFrame.select_dtypes(include=['dtype1','dtype2'])` returns a dataframe that only includes the datatypes `'dtype1'`, `'dtype2'`, etc.
#
# In this case we want to extract the numerical columns, so we will include `int64` and `float64`.

# %%
nums = Newton.select_dtypes(include=['int64','float64'])
display(nums.head(5))
# Out:
#    ZIP_OR_POSTAL_CODE    PRICE  BEDS  BATHS  SQUARE_FEET  LOT_SIZE  \
# 0                2459  1090000     3    3.0         2969     15014
# 1                2460   805000     3    2.5         1566      5582
# 2                2458   905000     4    2.5         2532      6273
# 3                2458  2660000     7    4.5         6748     26607
# 4                2460  1925000     4    4.0         4200     20446
#
#    YEAR_BUILT  DAYS_ON_MARKET  Per_SQUARE_FEET  HOA_MONTH  \
# 0        1967              19              367        NaN
# 1        1922              29              514        NaN
# 2        1953              19              357        NaN
# 3        1902               6              394        NaN
# 4        2007               2              458        NaN
#
#    NEXT OPEN HOUSE START TIME  NEXT OPEN HOUSE END TIME      MLS#   LATITUDE  \
# 0                         NaN                       NaN  72723436  42.295733
# 1                         NaN                       NaN  72721482  42.362241
# 2                         NaN                       NaN  72734897  42.345765
# 3                         NaN                       NaN  72623790  42.348963
# 4                         NaN                       NaN  72752876  42.349326
#
#    LONGITUDE
# 0 -71.177180
# 1 -71.208741
# 2 -71.175741
# 3 -71.187043
# 4 -71.212082

# %% [markdown]
# For an pair of features, we can form the scatter plot with `matplotlib`'s `plt.plot` function. Without any extra parameters, `plt.plot` returns a line plot, but we can set it to a scatter plot by including a format string, in this case `'o'` (lowercase o).
#
# * `ax.plot(x,y,'o')` Plots points whose $x$ coordinates are given in the first vector and whose $y$ coordinates are given in the second vector. The format string `'o'` indicates a scatter plot.
#
# To see some other options for formatting, take a look through matplotlibs own tutorial here: https://matplotlib.org/tutorials/introductory/pyplot.html

# %%
fig, ax = plt.subplots()

ax.plot(nums.LOT_SIZE,nums.PRICE,'x',color='Blue')
ax.set_xlabel("Lot Size", fontsize=20)
ax.set_ylabel("Sale Price", fontsize=20)
ax.set_title("Lots vs Sales", fontsize=20)
fig.set_size_inches(10, 7)
plt.show()

# %%
from sklearn import datasets, linear_model
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.linear_model import LinearRegression 

linear_regressor = LinearRegression()  # create object for the class
X=nums.LOT_SIZE.values.reshape(-1, 1)
Y=nums.PRICE.values.reshape(-1, 1)
linear_regressor.fit(X, Y)  # perform linear regression
Y_pred = linear_regressor.predict(X)  # make predictions
#plt.scatter(X, Y, color='Blue')
fig, ax = plt.subplots()

ax.plot(X,Y,'x',color='Blue')
plt.plot(X, Y_pred, color='red')
fig.set_size_inches(10, 7) 
plt.show()

# %% [markdown]
# Again, we can cut out the outliers using the logical index `z` from before.

# %%
fig, ax = plt.subplots()

ax.plot(nums[z].LOT_SIZE,nums[z].PRICE,'x',color='Blue')
ax.set_xlabel("Lot Size", fontsize=20)
ax.set_ylabel("Sale Price", fontsize=20)
ax.set_title("Lots vs Sales", fontsize=20)
fig.set_size_inches(10, 7)
plt.show()

# %%
linear_regressor = LinearRegression()  # create object for the class
X=nums[z].LOT_SIZE.values.reshape(-1, 1)
Y=nums[z].PRICE.values.reshape(-1, 1)
linear_regressor.fit(X, Y)  # perform linear regression
Y_pred = linear_regressor.predict(X)  # make predictions
#plt.scatter(X, Y, color='Blue')
fig, ax = plt.subplots()

ax.plot(X,Y,'x',color='Blue')
plt.plot(X, Y_pred, color='red')
fig.set_size_inches(10, 7) 
plt.show()

# %%
linear_regressor = LinearRegression()  # create object for the class
X=nums.LOT_SIZE.values.reshape(-1, 1)
Y=nums.PRICE.values.reshape(-1, 1)
linear_regressor.fit(X, Y)  # perform linear regression
Y_pred = linear_regressor.predict(X)  # make predictions
#plt.scatter(X, Y, color='Blue')
fig, ax = plt.subplots()

ax.plot(X,Y,'x',color='Blue')
plt.plot(X, Y_pred, color='red')
fig.set_size_inches(10, 7) 
plt.show()

# %% [markdown]
# And in fact we may just want to excise them all together:

# %%
numsc = nums[z]   ## Here, the c stands for "cleaned"

# %% [markdown]
# Lets compare some of the other data sets:

# %%
fig, ax = plt.subplots()

ax.plot(numsc.SQUARE_FEET,numsc.PRICE,'x',color='Blue')
ax.set_xlabel("Living Size", fontsize=20)
ax.set_ylabel("Sale Price", fontsize=20)
ax.set_title("Size vs Sales", fontsize=20)
fig.set_size_inches(10, 7)
plt.show()

# %%
fig, ax = plt.subplots()
ax.plot(nums.SQUARE_FEET,nums.PRICE,'x',color='Blue')
ax.set_xlabel("Living Size", fontsize=20)
ax.set_ylabel("Sale Price", fontsize=20)
ax.set_title("Size vs Sales", fontsize=20)
fig.set_size_inches(10, 7)
plt.show()

# %%
numsc.SQUARE_FEET.values
# Out:
# array([2969, 1566, 2532, 6748, 4200, 2232, 1344, 2898, 1729, 3149, 4000,
#        6430, 1750,  840, 2428, 3222, 1869, 1904, 3795, 3262, 3499, 5100,
#        5804, 4418, 1352, 1248, 1260, 2044, 3814, 1795, 1787, 1561, 2084,
#        2699, 3883, 1905, 4553, 5745, 5743, 2932, 5269, 2688, 3138, 1912,
#        3487, 3548, 1920, 5955, 4845, 5100, 1800, 5075, 3405, 4176, 6042,
#        2536, 6000, 4173])

# %% [markdown]
# # sklearn library for statistics

# %%
#import numpy as np
#import matplotlib.pyplot as plt  # To visualize
#import pandas as pd  # To read data
from sklearn import datasets, linear_model
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.linear_model import LinearRegression 

linear_regressor = LinearRegression()  # create object for the class
X=numsc.SQUARE_FEET.values.reshape(-1, 1)
Y=numsc.PRICE.values.reshape(-1, 1)
linear_regressor.fit(X, Y)  # perform linear regression
Y_pred = linear_regressor.predict(X)  # make predictions
#plt.scatter(X, Y, color='Blue')
fig, ax = plt.subplots()

ax.plot(X,Y,'x',color='Blue')
plt.plot(X, Y_pred, color='red')
fig.set_size_inches(10, 7) 
plt.show()

# %%
# Create linear regression object
regr = linear_model.LinearRegression()

# Train the model using the training sets
regr.fit(X, Y)

# Make predictions using the testing set
Y_pred = regr.predict(X)

print('Coefficients: \n', regr.coef_)
# The mean squared error
print('Mean squared error: %.2f'
      % mean_squared_error(Y, Y_pred))
# The coefficient of determination: 1 is perfect prediction
print('Coefficient of determination: %.2f'
      % r2_score(Y, Y_pred))
# Out:
# Coefficients:
#  [[460.36674808]]
# Mean squared error: 124776747373.62
# Coefficient of determination: 0.81

# %%
#Y_pred

# %%
fig, ax = plt.subplots(figsize=(10,7))
ax.plot(X,Y, 'bx', markersize=8, label='actual')
plt.plot(X, Y_pred, 'r-', linewidth=2, label='predict')

for i in range(len(X)):
    plt.plot([X[i], X[i]], [Y[i], Y_pred[i]],'g--',linewidth=1)

plt.legend()
plt.ylabel('Price', fontsize=14)
plt.xlabel('SQUARE FEET', fontsize=14)
#plt.title('Predict vs Actual', fontsize=25)
# ax[2].plot(names, values)
 
plt.show()

# %%
from mpl_toolkits.mplot3d import axes3d
import matplotlib.pyplot as plt

X=numsc.SQUARE_FEET 
Y=numsc.LOT_SIZE 
Z=numsc.PRICE

fig, ax = plt.subplots(figsize=(8, 8), subplot_kw={"projection": "3d"})

ax.scatter3D(X, Y, Z, zdir='z', c=None,s=20,cmap='Blue',color='Blue')


#ax.plot_wireframe(X,Y,Z, 'x',color='Blue', rstride=10, cstride=10)

#plt.tight_layout()
#plt.show()

# %%
linear_regressor = LinearRegression()  # create object for the class
X1=numsc.SQUARE_FEET.values.reshape(-1, 1)
X2=numsc.LOT_SIZE.values.reshape(-1, 1)
X = np.array([X1[:,0],X2[:,0]]).T 

Y=numsc.PRICE.values.reshape(-1, 1)
reg =linear_regressor.fit(X, Y)  # perform linear regression
Y_pred = linear_regressor.predict(X)  # make predictions
#plt.scatter(X, Y, color='Blue')
reg.coef_
# Out:
# array([[383.41973203,  24.28582035]])

# %%
reg.intercept_
# Out:
# array([9662.05354775])

# %%
xx, yy = np.meshgrid(range(0, 8000, 1000), range(0, 40000, 5000))
x = np.array([xx.flatten(),yy.flatten()]).T  
y_pred = linear_regressor.predict(x)

# %%
xx.shape
# Out:
# (8, 8)

# %%
y_p=y_pred.flatten().reshape(8,8)

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm

fig = plt.figure(figsize=(8, 8))
ax = fig.add_subplot(111, projection='3d')
 
ax.scatter3D(X1, X2, Y, zdir='z', c=None,s=20,cmap='Blue',color='Blue')

# plot the plane
ax.plot_surface(xx, yy, y_p, alpha=0.5,color='red')
 
    
plt.show()

# %% [markdown]
# #### Subplots
#
# To compare multiple features at once it's useful to create a matrix of side by side subplots. To create such a matrix, we edit the subplots call to include a shape vector describing the number of subplots we want
#
# * `fig, axes = plt.subpolots(m,n)` returns an `m` by `n` matrix of subplots. It stores the reference varisble for each subplot in the matrix of subplots in the list `axes`. It also returns a reference to the overall figure containing the subplots, which we store in `fig`. You can plot to the subplot in position (i,j) with `axes[i,j].plot(xvalues, yvalues)`.
#
# We can also specify the names inside the call to each plot

# %%
names
# Out:
# ['SALE_TYPE',
#  'SOLD_DATE',
#  'PROPERTY_TYPE',
#  'ADDRESS',
#  'CITY',
#  'STATE_OR_PROVINCE',
#  'ZIP_OR_POSTAL_CODE',
#  'PRICE',
#  'BEDS',
#  'BATHS',
#  'LOCATION',
#  'SQUARE_FEET',
#  'LOT_SIZE',
#  'YEAR_BUILT',
#  'DAYS_ON_MARKET',
#  'Per_SQUARE_FEET',
#  'HOA_MONTH',
#  'STATUS',
#  'NEXT OPEN HOUSE START TIME',
#  'NEXT OPEN HOUSE END TIME',
#  'URL (SEE http://www.redfin.com/buy-a-home/comparative-market-analysis FOR INFO ON PRICING)',
#  'SOURCE',
#  'MLS#',
#  'FAVORITE',
#  'INTERESTED',
#  'LATITUDE',
#  'LONGITUDE']

# %%
nnames = list(numsc)

# %%
fig, axes = plt.subplots(2,3, sharey=True)
fig.set_size_inches(15, 10)

axes[0,0].plot(numsc.BEDS,numsc.PRICE,'x',color='Blue')
axes[0,0].set_title(nnames[2], fontsize=12)
axes[0,1].plot(numsc.BATHS,numsc.PRICE,'x',color='Blue')
axes[0,1].set_title(nnames[3], fontsize=12)
axes[0,2].plot(numsc.SQUARE_FEET,numsc.PRICE,'x',color='Blue')
axes[0,2].set_title(nnames[4], fontsize=12)
axes[1,0].plot(numsc.LOT_SIZE,numsc.PRICE,'x',color='Blue')
axes[1,0].set_title(nnames[5], fontsize=12)
axes[1,1].plot(numsc.YEAR_BUILT,numsc.PRICE,'x',color='Blue')
axes[1,1].set_title(nnames[6], fontsize=12)
axes[1,2].plot(numsc.DAYS_ON_MARKET,numsc.PRICE,'x',color='Blue')
axes[1,2].set_title(nnames[7], fontsize=12)

plt.show()

# %% [markdown]
# We would like to see all scatterplots for all of the variables, properly named. To achive this we will loop through all of the data using a for loop. Using `list(numsc)` and the `len` function we can get the lenth of the list of column names for the numeric columns.

# %%
nnames = list(numsc)
len(nnames)
# Out:
# 15

# %% [markdown]
# We see that there are 38 columns containing numeric data, one of which contains the sales price. This can be roughly a $4\times 10$ grid.
#
# One way to display all of the scatter plots is to loop through the axes using two for loops, one running over the columns `m` and one over the rows `n`. The other way is to flatten the 2d array into a list of axes handlers and just loop through the list. In this case, we'd flatten our $4\times 10$ grid into a single vector of length 40 using `.reshape()`. For example,

# %%
A =  np.matrix([[0, 1],
                [2, 3],
                [4, 5],
                [6, 7]])
print(A)
print(A.reshape(2,4))
print(A.reshape(8))
# Out:
# [[0 1]
#  [2 3]
#  [4 5]
#  [6 7]]
# [[0 1 2 3]
#  [4 5 6 7]]
# [[0 1 2 3 4 5 6 7]]

# %% [markdown]
# For the grid of scatter plots we start with a 4 by 10 array, reshape it a length 40 array, and finally loop through it, plotting the scatter plots as we go. We do have to call the scatter plots by name, so we will actually use the `i`'th index of the `nnames` vector.
#
# We also want to label each axis, we can do this with
#
# `axes[i].set_title(nnames[i], fontsize=16)`

# %%
f, axes = plt.subplots(4, 4, sharey = True)
f.set_size_inches(15,15)
f.tight_layout()

axes = axes.reshape(16)

for i in range(0,15):
#    print(nnames[i])
    axes[i].plot(numsc[nnames[i]],numsc.PRICE,'x',color='Blue')
    axes[i].set_title(nnames[i], fontsize=12)

# %% [markdown]
# To clean this display up a bit, we can drop `id` from the list of numeric variables as it appears to be essentially random.

# %%
f, axes = plt.subplots(4, 4, sharey = True)
f.set_size_inches(15,15)
f.tight_layout()

axes = axes.reshape(16)

for i in range(0,14):
#    print(nnames[i])
    axes[i].plot(numsc[nnames[i+1]],numsc.PRICE,'x',color='Blue')
    axes[i].set_title(nnames[i+1], fontsize=16)

# %% [markdown]
# A quick glance immediately tells us which variables should be treated as discrete or ordinal (which we have to be more careful about fitting with linear regression) and which should be treated as interval or ratio (which is linear regression's natural setting).
#
# There are many type of plots we could produce this way. For exploratory data analysis another type of plot could include frequency data.

# %%
f, axes = plt.subplots(2, 5)
f.set_size_inches(18,8)
f.tight_layout()

axes = axes.reshape(10)

for i in range(1,6):
#    print(nnames[i])
    axes[i-1].plot(numsc[nnames[i+1]],numsc.PRICE,'x',color='Blue')
    axes[i-1].set_title(nnames[i+1], fontsize=16)
    
    z = numsc[nnames[i+1]].notnull()
    axes[i+4].hist(numsc[nnames[i+1]][z],bins=20, rwidth=.8)
    axes[i+4].set_ylabel("Count")

# %% [markdown]
# ## Correlation Plot
#
# As a last bit of exploratory analysis before moving on to prediction we will produce and plot the correlation matrix for the numerical features. To do so we will use Seaborn, a library for statistical data visualization built on top of `matplotlib`. There is of course the usual debate in the community about whether you should learn seaborn first, since it's easier and more elegant or if you should learn matplotlib first, since it's more fundamental.
#
# * `DataFrame.corr()` is a built in function that compute the correlation between the columns of a dataframe.
#
# We will use seaborns `sns.heatmap` function to produce a plot of all of the correlations. Seaborn often does an excellent job of displaying things on its own, but it is also deeply customization. In this case, we'll add a `linewidths=0.05` argument to make the correlation more distinct and use the `cmap="magma"` option to get a slightly more readable color scheme.

# %%
import pandas as pd

Newton=pd.read_csv("redfin_Newton2020Dec.csv", error_bad_lines=False)

# %%
nums = Newton.select_dtypes(include=['int64','float64']) # Get only numerical features
nums.head()


Newton1=numsc[['BEDS',
 'BATHS', 
 'SQUARE_FEET',
 'LOT_SIZE',
 'YEAR_BUILT',
 'DAYS_ON_MARKET','PRICE']]

Newton1.head()
# Out:
#    BEDS  BATHS  SQUARE_FEET  LOT_SIZE  YEAR_BUILT  DAYS_ON_MARKET    PRICE
# 0     3    3.0         2969     15014        1967              19  1090000
# 1     3    2.5         1566      5582        1922              29   805000
# 2     4    2.5         2532      6273        1953              19   905000
# 3     7    4.5         6748     26607        1902               6  2660000
# 4     4    4.0         4200     20446        2007               2  1925000

# %%
Newton1.describe()
# Out:
#             BEDS      BATHS  SQUARE_FEET      LOT_SIZE   YEAR_BUILT  \
# count  58.000000  58.000000    58.000000     58.000000    58.000000
# mean    4.293103   3.284483  3330.379310  12709.793103  1929.551724
# std     1.297888   1.478240  1573.350106   7656.194405    46.827857
# min     2.000000   1.500000   840.000000   3966.000000  1830.000000
# 25%     3.000000   2.500000  1906.750000   7365.750000  1897.750000
# 50%     4.000000   3.000000  3143.500000  10146.500000  1926.500000
# 75%     5.000000   4.000000  4363.500000  15004.500000  1953.000000
# max     8.000000   8.500000  6748.000000  33843.000000  2020.000000
#
#        DAYS_ON_MARKET         PRICE
# count       58.000000  5.800000e+01
# mean        14.534483  1.595263e+06
# std          8.364955  8.072190e+05
# min          1.000000  6.300000e+05
# 25%          6.250000  9.412500e+05
# 50%         15.000000  1.324250e+06
# 75%         21.000000  1.893750e+06
# max         29.000000  3.550000e+06

# %%
Newton1.corr()
# Out:
#                     BEDS     BATHS  SQUARE_FEET  LOT_SIZE  YEAR_BUILT  \
# BEDS            1.000000  0.650732     0.744928  0.505070    0.031643
# BATHS           0.650732  1.000000     0.827806  0.436802    0.417263
# SQUARE_FEET     0.744928  0.827806     1.000000  0.651106    0.261933
# LOT_SIZE        0.505070  0.436802     0.651106  1.000000   -0.159580
# YEAR_BUILT      0.031643  0.417263     0.261933 -0.159580    1.000000
# DAYS_ON_MARKET -0.354029 -0.379268    -0.428092 -0.189294   -0.216015
# PRICE           0.683499  0.687761     0.897301  0.716929    0.150803
#
#                 DAYS_ON_MARKET     PRICE
# BEDS                 -0.354029  0.683499
# BATHS                -0.379268  0.687761
# SQUARE_FEET          -0.428092  0.897301
# LOT_SIZE             -0.189294  0.716929
# YEAR_BUILT           -0.216015  0.150803
# DAYS_ON_MARKET        1.000000 -0.342381
# PRICE                -0.342381  1.000000

# %%
import pandas as pd
import seaborn as sns
fig,ax = plt.subplots(figsize=(14, 10))

#sns.set(font_scale=1.4)
sns.heatmap(Newton1.corr(), ax=ax, linewidths=0.05,cmap="magma",annot=True)
plt.show()

# %% [markdown]
# We see that __OverallQual__, __TotalBsmtSF__, __1stFlrSF__, __GarageArea__, __GrLivArea__, are all highly correlated with sales price. So high value houses have big garages, and large square footage and are overall of good quality.

# %%
Newton1.var()
# Out:
# BEDS              1.684513e+00
# BATHS             2.185194e+00
# SQUARE_FEET       2.475431e+06
# LOT_SIZE          5.861731e+07
# YEAR_BUILT        2.192848e+03
# DAYS_ON_MARKET    6.997247e+01
# PRICE             6.516025e+11
# dtype: float64

# %%
Newton1.cov()
#covariance of columns
# Out:
#                          BEDS          BATHS   SQUARE_FEET      LOT_SIZE  \
# BEDS                 1.684513       1.248488  1.521168e+03  5.018816e+03
# BATHS                1.248488       2.185194  1.925302e+03  4.943595e+03
# SQUARE_FEET       1521.167574    1925.302480  2.475431e+06  7.843136e+06
# LOT_SIZE          5018.816092    4943.594979  7.843136e+06  5.861731e+07
# YEAR_BUILT           1.923170      28.884150  1.929833e+04 -5.721322e+04
# DAYS_ON_MARKET      -3.843618      -4.689806 -5.634119e+03 -1.212312e+04
# PRICE           716088.243497  820680.462341  1.139606e+09  4.430783e+09
#
#                   YEAR_BUILT  DAYS_ON_MARKET         PRICE
# BEDS            1.923170e+00   -3.843618e+00  7.160882e+05
# BATHS           2.888415e+01   -4.689806e+00  8.206805e+05
# SQUARE_FEET     1.929833e+04   -5.634119e+03  1.139606e+09
# LOT_SIZE       -5.721322e+04   -1.212312e+04  4.430783e+09
# YEAR_BUILT      2.192848e+03   -8.461585e+01  5.700393e+06
# DAYS_ON_MARKET -8.461585e+01    6.997247e+01 -2.311880e+06
# PRICE           5.700393e+06   -2.311880e+06  6.516025e+11

# %%
fig,ax = plt.subplots(figsize=(14, 10))

#sns.set(font_scale=1.4)
sns.heatmap(Newton1.cov(), ax=ax, linewidths=0.05,cmap="magma",annot=True)
plt.show()

# %%
Newton1.describe()
# Out:
#             BEDS      BATHS  SQUARE_FEET      LOT_SIZE   YEAR_BUILT  \
# count  58.000000  58.000000    58.000000     58.000000    58.000000
# mean    4.293103   3.284483  3330.379310  12709.793103  1929.551724
# std     1.297888   1.478240  1573.350106   7656.194405    46.827857
# min     2.000000   1.500000   840.000000   3966.000000  1830.000000
# 25%     3.000000   2.500000  1906.750000   7365.750000  1897.750000
# 50%     4.000000   3.000000  3143.500000  10146.500000  1926.500000
# 75%     5.000000   4.000000  4363.500000  15004.500000  1953.000000
# max     8.000000   8.500000  6748.000000  33843.000000  2020.000000
#
#        DAYS_ON_MARKET         PRICE
# count       58.000000  5.800000e+01
# mean        14.534483  1.595263e+06
# std          8.364955  8.072190e+05
# min          1.000000  6.300000e+05
# 25%          6.250000  9.412500e+05
# 50%         15.000000  1.324250e+06
# 75%         21.000000  1.893750e+06
# max         29.000000  3.550000e+06

# %% [markdown]
# ## Simple Plotting for Categorical Data
#
# So far we have been discussing the numerical features only, but Seaborn provides many options for visualizing categorical features. The most basic the count plot and it will display number of each feature for a given category:

# %%
import seaborn as sns

ax = sns.countplot(x='SOLD_DATE', data=Newton)

# %% [markdown]
# We can select the categorical features be selecting the datatype as before, but this time we will select the `'object'` types.

# %%
cats = Newton.select_dtypes(include=['object'])
cats
# Out:
#     SALE_TYPE         SOLD_DATE              PROPERTY_TYPE  \
# 0   PAST SALE   December-4-2020  Single Family Residential
# 1   PAST SALE  November-24-2020  Single Family Residential
# 2   PAST SALE   December-4-2020  Single Family Residential
# 3   PAST SALE  December-17-2020  Single Family Residential
# 4   PAST SALE  December-21-2020  Single Family Residential
# 5   PAST SALE  December-17-2020  Single Family Residential
# 6   PAST SALE   December-2-2020  Single Family Residential
# 7   PAST SALE  November-24-2020  Single Family Residential
# 8   PAST SALE  November-25-2020  Single Family Residential
# 9   PAST SALE  November-25-2020  Single Family Residential
# 10  PAST SALE  December-18-2020  Single Family Residential
# 11  PAST SALE  December-14-2020  Single Family Residential
# 12  PAST SALE  December-18-2020  Single Family Residential
# 13  PAST SALE  November-25-2020  Single Family Residential
# 14  PAST SALE   December-1-2020  Single Family Residential
# 15  PAST SALE   December-3-2020  Single Family Residential
# 16  PAST SALE  December-17-2020  Single Family Residential
# 17  PAST SALE  December-18-2020  Single Family Residential
# 18  PAST SALE  November-30-2020  Single Family Residential
# 19  PAST SALE   December-7-2020  Single Family Residential
# 20  PAST SALE  December-22-2020  Single Family Residential
# 21  PAST SALE  December-17-2020  Single Family Residential
# 22  PAST SALE  December-17-2020  Single Family Residential
# 23  PAST SALE   December-4-2020  Single Family Residential
# 24  PAST SALE  December-18-2020  Single Family Residential
# 25  PAST SALE  November-24-2020  Single Family Residential
# 26  PAST SALE   December-7-2020  Single Family Residential
# 27  PAST SALE  December-10-2020  Single Family Residential
# 28  PAST SALE   December-2-2020  Single Family Residential
# 29  PAST SALE   December-4-2020  Single Family Residential
# 30  PAST SALE   December-1-2020  Single Family Residential
# 31  PAST SALE  November-30-2020  Single Family Residential
# 32  PAST SALE  December-11-2020  Single Family Residential
# 33  PAST SALE   December-3-2020  Single Family Residential
# 34  PAST SALE   December-8-2020  Single Family Residential
# 35  PAST SALE   December-9-2020  Single Family Residential
# 36  PAST SALE  December-15-2020  Single Family Residential
# 37  PAST SALE  December-21-2020  Single Family Residential
# 38  PAST SALE  December-21-2020  Single Family Residential
# 39  PAST SALE   December-8-2020  Single Family Residential
# 40  PAST SALE   December-1-2020  Single Family Residential
# 41  PAST SALE   December-1-2020  Single Family Residential
# 42  PAST SALE  November-30-2020  Single Family Residential
# 43  PAST SALE   December-2-2020  Single Family Residential
# 44  PAST SALE   December-8-2020  Single Family Residential
# 45  PAST SALE   December-8-2020  Single Family Residential
# 46  PAST SALE  December-11-2020  Single Family Residential
# 47  PAST SALE  December-14-2020  Single Family Residential
# 48  PAST SALE  December-16-2020  Single Family Residential
# 49  PAST SALE  December-18-2020  Single Family Residential
# 50  PAST SALE  December-10-2020  Single Family Residential
# 51  PAST SALE  December-15-2020  Single Family Residential
# 52  PAST SALE  December-16-2020  Single Family Residential
# 53  PAST SALE   December-2-2020  Single Family Residential
# 54  PAST SALE  December-22-2020  Single Family Residential
# 55  PAST SALE  December-15-2020  Single Family Residential
# 56  PAST SALE   December-2-2020  Single Family Residential
# 57  PAST SALE  December-18-2020  Single Family Residential
# 58  PAST SALE   December-3-2020  Single Family Residential
#
#                   ADDRESS    CITY STATE_OR_PROVINCE                  LOCATION  \
# 0         95 Peregrine Rd  Newton                MA                    Newton
# 1       503 California St  Newton                MA                    Newton
# 2      6 Valley Spring Rd  Newton                MA             Newton Corner
# 3           650 Centre St  Newton                MA             Newton Center
# 4       19 Gray Birch Ter  Newton                MA               West Newton
# 5         50 Jefferson St  Newton                MA                    Newton
# 6          100 Gardner St  Newton                MA             Newton Corner
# 7         23 Marcellus Dr  Newton                MA                    Newton
# 8         101 Falmouth Rd  Newton                MA               West Newton
# 9            114 Derby St  Newton                MA               West Newton
# 10    169 Mount Vernon St  Newton                MA               West Newton
# 11          29 Sylvan Ave  Newton                MA               West Newton
# 12           18 Tudor Ter  Newton                MA                Auburndale
# 13        11 Colonial Ave  Newton                MA                    Newton
# 14          211 Crafts St  Newton                MA               Newtonville
# 15             77 Otis St  Newton                MA                    Newton
# 16      59 Trowbridge Ave  Newton                MA               Newtonville
# 17            23 Smith Ct  Newton                MA               West Newton
# 18            109 High St  Newton                MA        Newton Upper Falls
# 19          134 Spiers Rd  Newton                MA             Oak Hill Park
# 20      107 Mary Ellen Rd  Newton                MA                     Waban
# 21          19 Shute Path  Newton                MA             Newton Center
# 22          275 Dudley Rd  Newton                MA             Newton Center
# 23         33 Hancock Ave  Newton                MA             Newton Centre
# 24         15 Hancock Ave  Newton                MA             Newton Center
# 25            44 Lewis St  Newton                MA                    Newton
# 26          21 Oakwood Rd  Newton                MA                Auburndale
# 27             19 Fern St  Newton                MA                Auburndale
# 28         17 Brandeis Rd  Newton                MA                  Oak Hill
# 29           139 Gibbs St  Newton                MA             Newton Center
# 30        18 Mountfort Rd  Newton                MA          Newton Highlands
# 31         62 Theodore Rd  Newton                MA             Thompsonville
# 32           57 Cherry Pl  Newton                MA               West Newton
# 33          185 Nevada St  Newton                MA               Newtonville
# 34             8 Eden Ave  Newton                MA               West Newton
# 35        218 Franklin St  Newton                MA                    Newton
# 36             44 King St  Newton                MA                Auburndale
# 37         146 Fairway Dr  Newton                MA               West Newton
# 38          134 Dorset Rd  Newton                MA                     Waban
# 39          390 Dedham St  Newton                MA                    Newton
# 40          17 Cushing St  Newton                MA          Newton Highlands
# 41            62 Lenox St  Newton                MA          West Newton Hill
# 42  1488 Commonwealth Ave  Newton                MA    Brae Burn Country Club
# 43       266 Highland Ave  Newton                MA          West Newton Hill
# 44            19 Blake St  Newton                MA               Newtonville
# 45            49 Clyde St  Newton                MA               Newtonville
# 46  1830 Commonwealth Ave  Newton                MA                    Newton
# 47          192 Evelyn Rd  Newton                MA                     Waban
# 48          258 Prince St  Newton                MA                    Newton
# 49        22 Kirkstall Rd  Newton                MA                    Newton
# 50          48 Bernard St  Newton                MA                    Newton
# 51          92 Upland Ave  Newton                MA          Newton Highlands
# 52         11 Clovelly Rd  Newton                MA        Olde Chestnut Hill
# 53          73 Puritan Rd  Newton                MA                     Waban
# 54       203 Greenwood St  Newton                MA                    Newton
# 55         45 Village Cir  Newton                MA  Newton Center / Oak Hill
# 56   542 Commonwealth Ave  Newton                MA                    Newton
# 57        30 Columbine Rd  Newton                MA                    Newton
# 58   700 Commonwealth Ave  Newton                MA             Newton Center
#
#    STATUS  \
# 0    Sold
# 1    Sold
# 2    Sold
# 3    Sold
# 4    Sold
# 5    Sold
# 6    Sold
# 7    Sold
# 8    Sold
# 9    Sold
# 10   Sold
# 11   Sold
# 12   Sold
# 13   Sold
# 14   Sold
# 15   Sold
# 16   Sold
# 17   Sold
# 18   Sold
# 19   Sold
# 20   Sold
# 21   Sold
# 22   Sold
# 23   Sold
# 24   Sold
# 25   Sold
# 26   Sold
# 27   Sold
# 28   Sold
# 29   Sold
# 30   Sold
# 31   Sold
# 32   Sold
# 33   Sold
# 34   Sold
# 35   Sold
# 36   Sold
# 37   Sold
# 38   Sold
# 39   Sold
# 40   Sold
# 41   Sold
# 42   Sold
# 43   Sold
# 44   Sold
# 45   Sold
# 46   Sold
# 47   Sold
# 48   Sold
# 49   Sold
# 50   Sold
# 51   Sold
# 52   Sold
# 53   Sold
# 54   Sold
# 55   Sold
# 56   Sold
# 57   Sold
# 58   Sold
#
#    URL (SEE http://www.redfin.com/buy-a-home/comparative-market-analysis FOR INFO ON PRICING)  \
# 0   http://www.redfin.com/MA/Newton/95-Peregrine-R...
# 1   http://www.redfin.com/MA/Newton/503-California...
# 2   http://www.redfin.com/MA/Newton/6-Valley-Sprin...
# 3   http://www.redfin.com/MA/Newton/650-Centre-St-...
# 4   http://www.redfin.com/MA/Newton/19-Gray-Birch-...
# 5   http://www.redfin.com/MA/Newton/50-Jefferson-S...
# 6   http://www.redfin.com/MA/Newton/100-Gardner-St...
# 7   http://www.redfin.com/MA/Newton/23-Marcellus-D...
# 8   http://www.redfin.com/MA/Newton/101-Falmouth-R...
# 9   http://www.redfin.com/MA/Newton/114-Derby-St-0...
# 10  http://www.redfin.com/MA/Newton/169-Mt-Vernon-...
# 11  http://www.redfin.com/MA/Newton/29-Sylvan-Ave-...
# 12  http://www.redfin.com/MA/Auburndale/18-Tudor-T...
# 13  http://www.redfin.com/MA/Newton/11-Colonial-Av...
# 14  http://www.redfin.com/MA/Newton/211-Crafts-St-...
# 15  http://www.redfin.com/MA/Newton/77-Otis-St-024...
# 16  http://www.redfin.com/MA/Newton/59-Trowbridge-...
# 17  http://www.redfin.com/MA/Newton/23-Smith-Ct-02...
# 18  http://www.redfin.com/MA/Newton/109-High-St-02...
# 19  http://www.redfin.com/MA/Newton/134-Spiers-Rd-...
# 20  http://www.redfin.com/MA/Waban/107-Mary-Ellen-...
# 21  http://www.redfin.com/MA/Newton/19-Shute-Path-...
# 22  http://www.redfin.com/MA/Newton/275-Dudley-Rd-...
# 23  http://www.redfin.com/MA/Newton/33-Hancock-Ave...
# 24  http://www.redfin.com/MA/Newton/15-Hancock-Ave...
# 25  http://www.redfin.com/MA/Newton/44-Lewis-St-02...
# 26  http://www.redfin.com/MA/Auburndale/21-Oakwood...
# 27  http://www.redfin.com/MA/Auburndale/19-Fern-St...
# 28  http://www.redfin.com/MA/Newton/17-Brandeis-Rd...
# 29  http://www.redfin.com/MA/Newton/139-Gibbs-St-0...
# 30  http://www.redfin.com/MA/Newton/18-Mountfort-R...
# 31  http://www.redfin.com/MA/Newton/62-Theodore-Rd...
# 32  http://www.redfin.com/MA/Newton/57-Cherry-Pl-0...
# 33  http://www.redfin.com/MA/Newton/185-Nevada-St-...
# 34  http://www.redfin.com/MA/Newton/8-Eden-Ave-024...
# 35  http://www.redfin.com/MA/Newton/218-Franklin-S...
# 36  http://www.redfin.com/MA/Auburndale/44-King-St...
# 37  http://www.redfin.com/MA/Newton/146-Fairway-Dr...
# 38  http://www.redfin.com/MA/WABAN/134-DORSET-RD-0...
# 39  http://www.redfin.com/MA/Newton/390-Dedham-St-...
# 40  http://www.redfin.com/MA/Newton/17-Cushing-St-...
# 41  http://www.redfin.com/MA/Newton/62-Lenox-St-02...
# 42  http://www.redfin.com/MA/Newton/1488-Commonwea...
# 43  http://www.redfin.com/MA/Newton/266-Highland-A...
# 44  http://www.redfin.com/MA/Newton/19-Blake-St-02...
# 45  http://www.redfin.com/MA/Newton/49-Clyde-St-02...
# 46  http://www.redfin.com/MA/Auburndale/1830-Commo...
# 47  http://www.redfin.com/MA/Waban/192-Evelyn-Rd-0...
# 48  http://www.redfin.com/MA/Newton/258-Prince-St-...
# 49  http://www.redfin.com/MA/Newton/22-Kirkstall-R...
# 50  http://www.redfin.com/MA/Newton/48-Bernard-St-...
# 51  http://www.redfin.com/MA/Newton/92-Upland-Ave-...
# 52  http://www.redfin.com/MA/Chestnut-Hill/11-Clov...
# 53  http://www.redfin.com/MA/Waban/73-Puritan-Rd-0...
# 54  http://www.redfin.com/MA/Newton/203-Greenwood-...
# 55  http://www.redfin.com/MA/Newton/45-Village-Cir...
# 56  http://www.redfin.com/MA/Newton/542-Commonweal...
# 57  http://www.redfin.com/MA/Newton/30-Columbine-R...
# 58  http://www.redfin.com/MA/Newton-Centre/700-Com...
#
#      SOURCE FAVORITE INTERESTED
# 0   MLS PIN        N          Y
# 1   MLS PIN        N          Y
# 2   MLS PIN        N          Y
# 3   MLS PIN        N          Y
# 4   MLS PIN        N          Y
# 5   MLS PIN        N          Y
# 6   MLS PIN        N          Y
# 7   MLS PIN        N          Y
# 8   MLS PIN        N          Y
# 9   MLS PIN        N          Y
# 10  MLS PIN        N          Y
# 11  MLS PIN        N          Y
# 12  MLS PIN        N          Y
# 13  MLS PIN        N          Y
# 14  MLS PIN        N          Y
# 15  MLS PIN        N          Y
# 16  MLS PIN        N          Y
# 17  MLS PIN        N          Y
# 18  MLS PIN        N          Y
# 19  MLS PIN        N          Y
# 20  MLS PIN        N          Y
# 21  MLS PIN        N          Y
# 22  MLS PIN        N          Y
# 23  MLS PIN        N          Y
# 24  MLS PIN        N          Y
# 25  MLS PIN        N          Y
# 26  MLS PIN        N          Y
# 27  MLS PIN        N          Y
# 28  MLS PIN        N          Y
# 29  MLS PIN        N          Y
# 30  MLS PIN        N          Y
# 31  MLS PIN        N          Y
# 32  MLS PIN        N          Y
# 33  MLS PIN        N          Y
# 34  MLS PIN        N          Y
# 35  MLS PIN        N          Y
# 36  MLS PIN        N          Y
# 37  MLS PIN        N          Y
# 38  MLS PIN        N          Y
# 39  MLS PIN        N          Y
# 40  MLS PIN        N          Y
# 41  MLS PIN        N          Y
# 42  MLS PIN        N          Y
# 43  MLS PIN        N          Y
# 44  MLS PIN        N          Y
# 45  MLS PIN        N          Y
# 46  MLS PIN        N          Y
# 47  MLS PIN        N          Y
# 48  MLS PIN        N          Y
# 49  MLS PIN        N          Y
# 50  MLS PIN        N          Y
# 51  MLS PIN        N          Y
# 52  MLS PIN        N          Y
# 53  MLS PIN        N          Y
# 54  MLS PIN        N          Y
# 55  MLS PIN        N          Y
# 56  MLS PIN        N          Y
# 57  MLS PIN        N          Y
# 58  MLS PIN        N          Y

# %% [markdown]
# For each feature, we can find the count for each category using `pd.value_counts()`. For example, for the neighborhood we find

# %%
print(cats['SOLD_DATE'].value_counts())
sns.countplot(x="SOLD_DATE", data=cats)
# Out:
# December-18-2020    6
# December-2-2020     5
# December-17-2020    5
# December-1-2020     4
# December-4-2020     4
# December-8-2020     4
# November-30-2020    3
# November-24-2020    3
# November-25-2020    3
# December-21-2020    3
# December-3-2020     3
# December-15-2020    3
# December-11-2020    2
# December-22-2020    2
# December-7-2020     2
# December-16-2020    2
# December-14-2020    2
# December-10-2020    2
# December-9-2020     1
# Name: SOLD_DATE, dtype: int64
# <AxesSubplot:xlabel='SOLD_DATE', ylabel='count'>

# %% [markdown]
# We can then rotate the labels to be more readable using `sns.set_ticklabels(rotate=)` as below:

# %%
cp = sns.countplot(x="SOLD_DATE", data=cats)
cp.set_xticklabels(cp.get_xticklabels(),rotation=80)
# Out:
# [Text(0, 0, 'December-4-2020'),
#  Text(1, 0, 'November-24-2020'),
#  Text(2, 0, 'December-17-2020'),
#  Text(3, 0, 'December-21-2020'),
#  Text(4, 0, 'December-2-2020'),
#  Text(5, 0, 'November-25-2020'),
#  Text(6, 0, 'December-18-2020'),
#  Text(7, 0, 'December-14-2020'),
#  Text(8, 0, 'December-1-2020'),
#  Text(9, 0, 'December-3-2020'),
#  Text(10, 0, 'November-30-2020'),
#  Text(11, 0, 'December-7-2020'),
#  Text(12, 0, 'December-22-2020'),
#  Text(13, 0, 'December-10-2020'),
#  Text(14, 0, 'December-11-2020'),
#  Text(15, 0, 'December-8-2020'),
#  Text(16, 0, 'December-9-2020'),
#  Text(17, 0, 'December-15-2020'),
#  Text(18, 0, 'December-16-2020')]

# %% [markdown]
# ### Categorical Scatter Plots (New in seaborn 0.9)
#
# Categorical scatter plots allow us to display continuous numerical data against the categories. For example, to display housing price against neighborhood, we use `sns.catplot`:

# %%
cp = sns.catplot(x="SOLD_DATE", y="PRICE", data=Newton);
cp.set_xticklabels(rotation=80)

# %% [markdown]
# For further information about using Seaborn to plot categorical data, take a look at the guide here:
#
# https://seaborn.pydata.org/tutorial/categorical.html

# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import statsmodels.api as sm
from statsmodels.sandbox.regression.predstd import wls_prediction_std
import statsmodels.formula.api as smf

np.random.seed(9876789)

# %% [markdown]
# Reference: https://github.com/JWarmenhoven/ISLR-python/blob/master/Notebooks/Chapter%203.ipynb

# %%
X=numsc[['BEDS',
 'BATHS', 
 'SQUARE_FEET',
 'LOT_SIZE',
 'YEAR_BUILT',
 'DAYS_ON_MARKET']]
Y=numsc[['PRICE']]

# %%
est=smf.ols('PRICE ~ BEDS + BATHS+SQUARE_FEET+LOT_SIZE+YEAR_BUILT+DAYS_ON_MARKET', data=Newton1).fit()

# %%
est.summary().tables[1]
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %%
est.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  PRICE   R-squared:                       0.840
# Model:                            OLS   Adj. R-squared:                  0.822
# Method:                 Least Squares   F-statistic:                     44.77
# Date:                Sun, 31 Jan 2021   Prob (F-statistic):           1.23e-18
# Time:                        09:48:35   Log-Likelihood:                -817.45
# No. Observations:                  58   AIC:                             1649.
# Df Residuals:                      51   BIC:                             1663.
# Df Model:                           6
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# Intercept      -8.325e+05   2.42e+06     -0.345      0.732   -5.68e+06    4.02e+06
# BEDS            2.758e+04   5.54e+04      0.498      0.621   -8.37e+04    1.39e+05
# BATHS          -6.669e+04   6.01e+04     -1.110      0.272   -1.87e+05    5.39e+04
# SQUARE_FEET      426.2288     70.623      6.035      0.000     284.448     568.010
# LOT_SIZE          22.7860      8.788      2.593      0.012       5.142      40.429
# YEAR_BUILT       403.8031   1240.964      0.325      0.746   -2087.535    2895.142
# DAYS_ON_MARKET  2761.0021   6061.426      0.456      0.651   -9407.819    1.49e+04
# ==============================================================================
# Omnibus:                        2.961   Durbin-Watson:                   2.031
# Prob(Omnibus):                  0.227   Jarque-Bera (JB):                2.062
# Skew:                          -0.328   Prob(JB):                        0.357
# Kurtosis:                       3.650   Cond. No.                     8.25e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 8.25e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# # Subset selection:
