# %% [markdown]
# # Lab 2: Methods in Linear Regression
#
# ## Problems:
#
# ### Problem 1: Bootstrapping a Confidence Interval
#
# If we don't have a formula for the confidence interval of a statistic, we can often estimate it by sampling from out data set many times, computing the statistic of interest, and then plotting the distribution. This is known as __bootstrapping__ the confidence interval, since you're using the data to make estimates about your fits, effectively pulling yourself up by your bootstraps. In this problem, we will see how to boot strap the confidence interval for the $\beta$ parameters in the linear fit.
#
# __Continue with the Lab2 Master file.__ Lets return to the one variable examples of fitting the sales price to the first floor square footage __1stFlrSF__. Using a for loop, compute $\beta_0$ and $\beta_1$ 1000 times for samples of size $N = 1436$ __with replacement__ and store their results in vectors, as in the code below.

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression
import math
from scipy import stats

import io
import requests

# If there is a problem loading the data, download the data file first. 
url = "https://raw.githubusercontent.com/tipthederiver/Math-7243-2020/master/Datasets/Ames/train.csv"
s = requests.get(url).content
ames = pd.read_csv(io.StringIO(s.decode('utf-8')))
ames
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
#      LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 0            Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1            Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 2            Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 3            Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 4            Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# ...          ...       ...  ...      ...    ...    ...         ...     ...
# 1455         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1456         Lvl    AllPub  ...        0    NaN  MnPrv         NaN       0
# 1457         Lvl    AllPub  ...        0    NaN  GdPrv        Shed    2500
# 1458         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1459         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
#
#      MoSold YrSold  SaleType  SaleCondition  SalePrice
# 0         2   2008        WD         Normal     208500
# 1         5   2007        WD         Normal     181500
# 2         9   2008        WD         Normal     223500
# 3         2   2006        WD        Abnorml     140000
# 4        12   2008        WD         Normal     250000
# ...     ...    ...       ...            ...        ...
# 1455      8   2007        WD         Normal     175000
# 1456      2   2010        WD         Normal     210000
# 1457      5   2010        WD         Normal     266500
# 1458      4   2010        WD         Normal     142125
# 1459      6   2008        WD         Normal     147500
#
# [1460 rows x 81 columns]

# %%
z = ames['GrLivArea']+ames['BsmtUnfSF']<4000
print("Number of records removed:",len(ames) - sum(z))
data = ames[z]
# Out:
# Number of records removed: 24

# %%
data = data.select_dtypes(include=['int64','float64'])
data = data.drop(columns='MSSubClass')

# %% [markdown]
# __Turn in__
#
# 1. Plot a histogram of $\beta_0$ and $\beta_1$.
# 2. Using `beta0.sort()`, sort the values and find the interval containing the middle 950 values. This is the bootstrap 95% confidence interval.
# 3. Using the formulas from (Section 4.Statistics for ML. Sec4StatisticsML.pdf page 17.), compute the confidence interval. Remember that here you use all of the training data. Compare your results.

# %%
N = 1000
Test_Size = 1159

beta0 = np.zeros(N)
beta1 = np.zeros(N)

for i in range(N):
    random_state = i+1
    
    train=data.sample(n=Test_Size,replace=False,random_state=random_state)
    test=data.drop(train.index)

    X_train = train.drop(columns=['SalePrice','Id'])
    Y_train = train['SalePrice']

    X_test = test.drop(columns=['SalePrice','Id'])
    Y_test = test['SalePrice']

    X = np.matrix(X_train['1stFlrSF'])
    Y = np.matrix(Y_train)

    X = X.reshape(-1,1)
    Y = Y.reshape(-1,1)

    lr = LinearRegression()
    model = lr.fit(X,Y)
    beta0[i] = lr.intercept_
    beta1[i] = lr.coef_

# %%
fig, ax = plt.subplots(1, 2, figsize=(16,6))
sns.distplot(beta0, ax=ax[0])
ax[0].set_title('beta0')
sns.distplot(beta1, ax=ax[1])
ax[1].set_title('beta1')
# Out:
# D:\Anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# D:\Anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0.5, 1.0, 'beta1')

# %% [markdown]
# # Bootstrap 95% confidence interval.

# %%
beta0.sort()
beta0_middle950 = beta0[25:975]

beta0_95per_CI = (beta0[25], beta0[975])
print(beta0_95per_CI)
# Out:
# (31657.799858580576, 43435.047388976964)

# %%
beta1.sort()
beta1_middle950 = beta1[25:975]

beta1_95per_CI = (beta1[25], beta1[975])
print(beta1_95per_CI)
# Out:
# (116.16891157607516, 127.03128969062415)

# %% [markdown]
# # Computing the confidence interval

# %%
X_train = data.drop(columns=['SalePrice','Id'])
Y_train = data['SalePrice']

X = np.matrix(X_train['1stFlrSF']).reshape(-1, 1)
Y = np.matrix(Y_train).reshape(-1, 1)

lr = LinearRegression()
lr.fit(X, Y)
beta0_hat = lr.intercept_
beta1_hat = lr.coef_

# %%
beta0_hat, beta1_hat
# Out:
# (array([37565.75331143]), array([[121.75626859]]))

# %%
X1 = np.concatenate([np.ones_like(X), X], axis=1)

# %%
def RSS(y,Y):
    y = np.matrix(y).reshape(-1,1)
    Y = np.matrix(Y).reshape(-1,1)
    
    return (y-Y).T*(y-Y)

# %%
rss_theta = RSS(lr.predict(X), Y)

n = X.shape[0]
d = 2
n_minus_d_minus_1 = n-d-1

s_square = rss_theta/n_minus_d_minus_1
s = math.sqrt(s_square)
print(s)

t_val = stats.t.ppf(1-0.05/2, n_minus_d_minus_1)

print(t_val, s)
# Out:
# 57036.372428918185
# 1.9616208178398542 57036.372428918185

# %%
X_transpose_X_inv = np.linalg.inv(np.matmul(X1.T, X1))

# beta0 confidence interval
beta0_95per_CI_stat = (beta0_hat - t_val*s*math.sqrt(X_transpose_X_inv[0,0]), beta0_hat + t_val*s*math.sqrt(X_transpose_X_inv[0,0]))
# beta0 confidence interval
beta1_95per_CI_stat = (beta1_hat - t_val*s*math.sqrt(X_transpose_X_inv[1,1]), beta1_hat + t_val*s*math.sqrt(X_transpose_X_inv[1,1]))

beta0_95per_CI_stat = beta0_95per_CI_stat[0][0], beta0_95per_CI_stat[1][0]
beta1_95per_CI_stat = beta1_95per_CI_stat[0][0][0], beta1_95per_CI_stat[1][0][0]

# %%
#comparing 95% confidence interval of $\beta_0, \beta_1$ calculated empirically and
#from statistics formula for computing the confidence intervals

print('beta0 CI empirical: ', beta0_95per_CI)
print('beta0 CI from stats:', beta0_95per_CI_stat)
print('-------------------------------------')
print('beta1 CI empirical: ', beta1_95per_CI)
print('beta1 CI from stats:', beta1_95per_CI_stat)
# Out:
# beta0 CI empirical:  (31657.799858580576, 43435.047388976964)
# beta0 CI from stats: (27662.29458876108, 47469.21203409755)
# -------------------------------------
# beta1 CI empirical:  (116.16891157607516, 127.03128969062415)
# beta1 CI from stats: (113.51411467565866, 129.99842250729137)

# %% [markdown]
# We can see that values of $\beta_0, \beta_1$ are very close to each other.

# %% [markdown]
# ###### Problem 2: Linear Methods on High Dimensional Data
#
# Perform ridge regression and lasso regression on the MRI Slices dataset on blackboard. You should follow the __Loading the Viewing MRI Slices__ notebook, eventually loading all slices into Python as a data matrix, with all picture dimensions flattened. The text and code for that process has been reproduced below.
#
# We want to fit the MRI Slices data to the __Normalized Whole-brain Volume (nWBV)__ in the labels data.
#
#
# __Turn in__:
#
# 1. Given the train-test split with seed random_state=$255$, what is the best $\alpha$ value for pure Ridge Regression? Justify your answer.
# 2. Given the train-test split with seed random_state=$255$, what is the best $\lambda$ value for pure Lasso Regression? Justify your answer.
# 3. (Bonus) What is the best $(\alpha,\lambda)$ value for elastic net regression?
#
# You may set the downsample rate to higher you are unable to compute the linear model.
#
# random_state= 255 will fix the random set. See Wiki for a quick explanation.  https://en.wikipedia.org/wiki/Random_seed
# Or https://machinelearningmastery.com/train-test-split-for-evaluating-machine-learning-algorithms/ for some more details.
#
# ### Load MRI All Files
#
# To load all of the files into an array we need to be able to search through the directory. Luckily, this is easy to do using the labels file, since each file name is stored there. We just need to loop through the __Filename__ column in the `labels` dataset and load them into an array one by one. There are 702 files in total.
#
# With the array there are two ways we can load them in: First, we can load them into a $609\times 176 \times 176$ array, which is the best option if we care about the 2D structure. However for algorithms like linear regression that can not see the 2D structure, we may want to flatten the images to a $609\times 30976$ array (note that $30976 = 176 \times 176$). Its easy enough two switch back and forth between the two array structures later. We will start with the flattened array.

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import matplotlib
from sklearn.model_selection import train_test_split
from tqdm import tqdm
import statsmodels.api as sm


file_dir = 'E:/Math/NEU/MATH7243/Labs/MRI_Images/'

labels = pd.read_csv(file_dir + 'labels-1.csv')
display(labels)
# Out:
#      Unnamed: 0               Filename             ID M/F Hand  Age  Educ  \
# 0             0   OAS1_0001_MR1_55.png  OAS1_0001_MR1   F    R   74     2
# 1             1  OAS1_0001_MR1_120.png  OAS1_0001_MR1   F    R   74     2
# 2             2  OAS1_0001_MR1_180.png  OAS1_0001_MR1   F    R   74     2
# 3             3   OAS1_0002_MR1_55.png  OAS1_0002_MR1   F    R   55     4
# 4             4  OAS1_0002_MR1_120.png  OAS1_0002_MR1   F    R   55     4
# ..          ...                    ...            ...  ..  ...  ...   ...
# 604         604  OAS1_0449_MR1_120.png  OAS1_0449_MR1   F    R   71     3
# 605         605  OAS1_0449_MR1_180.png  OAS1_0449_MR1   F    R   71     3
# 606         606   OAS1_0456_MR1_55.png  OAS1_0456_MR1   M    R   61     5
# 607         607  OAS1_0456_MR1_120.png  OAS1_0456_MR1   M    R   61     5
# 608         608  OAS1_0456_MR1_180.png  OAS1_0456_MR1   M    R   61     5
#
#      SES  MMSE  CDR  eTIV   nWBV    ASF  Delay  Slice
# 0    3.0    29  0.0  1344  0.743  1.306    NaN     55
# 1    3.0    29  0.0  1344  0.743  1.306    NaN    120
# 2    3.0    29  0.0  1344  0.743  1.306    NaN    180
# 3    1.0    29  0.0  1147  0.810  1.531    NaN     55
# 4    1.0    29  0.0  1147  0.810  1.531    NaN    120
# ..   ...   ...  ...   ...    ...    ...    ...    ...
# 604  4.0    29  0.0  1264  0.818  1.388    NaN    120
# 605  4.0    29  0.0  1264  0.818  1.388    NaN    180
# 606  2.0    30  0.0  1637  0.780  1.072    NaN     55
# 607  2.0    30  0.0  1637  0.780  1.072    NaN    120
# 608  2.0    30  0.0  1637  0.780  1.072    NaN    180
#
# [609 rows x 15 columns]

# %%
DS = 8             # Downsample rate, must be a multiple of 30976

if 30976/DS % 1 > 0:
    print("Downsample rate is not a multiple of 30976")
    DS = 1
    im_size = 30976
else:
    im_size = int(30976/DS)


data = np.zeros([609, im_size])

for i, file_name in enumerate(labels.Filename):
    img = np.mean(matplotlib.image.imread(file_dir + file_name),axis=2).reshape(-1)
    data[i,:] = img[::DS]            # Downsample the image

# %%
print(data.shape)
print(labels.shape)
sns.histplot(labels['nWBV'])
# Out:
# (609, 3872)
# (609, 15)
# <AxesSubplot:xlabel='nWBV', ylabel='Count'>

# %%
ols = sm.OLS(Y_train, sm.add_constant(X_train))
ols_result = ols.fit_regularized(L1_wt=0,alpha=1)

Rs(ols_result.predict(sm.add_constant(X_test)),Y_test)
# Out:
# ---------------------------------------------------------------------------
# MissingDataError                          Traceback (most recent call last)
# <ipython-input-18-d897ed7766d4> in <module>
# ----> 1 ols = sm.OLS(Y_train, sm.add_constant(X_train))
#       2 ols_result = ols.fit_regularized(L1_wt=0,alpha=1)
#       3
#       4 Rs(ols_result.predict(sm.add_constant(X_test)),Y_test)
#
# D:\Anaconda3\lib\site-packages\statsmodels\regression\linear_model.py in __init__(self, endog, exog, missing, hasconst, **kwargs)
#     870     def __init__(self, endog, exog=None, missing='none', hasconst=None,
#     871                  **kwargs):
# --> 872         super(OLS, self).__init__(endog, exog, missing=missing,
#     873                                   hasconst=hasconst, **kwargs)
#     874         if "weights" in self._init_keys:
#
# D:\Anaconda3\lib\site-packages\statsmodels\regression\linear_model.py in __init__(self, endog, exog, weights, missing, hasconst, **kwargs)
#     701         else:
#     702             weights = weights.squeeze()
# --> 703         super(WLS, self).__init__(endog, exog, missing=missing,
#     704                                   weights=weights, hasconst=hasconst, **kwargs)
#     705         nobs = self.exog.shape[0]
#
# D:\Anaconda3\lib\site-packages\statsmodels\regression\linear_model.py in __init__(self, endog, exog, **kwargs)
#     188     """
#     189     def __init__(self, endog, exog, **kwargs):
# --> 190         super(RegressionModel, self).__init__(endog, exog, **kwargs)
#     191         self._data_attr.extend(['pinv_wexog', 'weights'])
#     192
#
# D:\Anaconda3\lib\site-packages\statsmodels\base\model.py in __init__(self, endog, exog, **kwargs)
#     235
#     236     def __init__(self, endog, exog=None, **kwargs):
# --> 237         super(LikelihoodModel, self).__init__(endog, exog, **kwargs)
#     238         self.initialize()
#     239
#
# D:\Anaconda3\lib\site-packages\statsmodels\base\model.py in __init__(self, endog, exog, **kwargs)
#      75         missing = kwargs.pop('missing', 'none')
#      76         hasconst = kwargs.pop('hasconst', None)
# ---> 77         self.data = self._handle_data(endog, exog, missing, hasconst,
#      78                                       **kwargs)
#      79         self.k_constant = self.data.k_constant
#
# D:\Anaconda3\lib\site-packages\statsmodels\base\model.py in _handle_data(self, endog, exog, missing, hasconst, **kwargs)
#      99
#     100     def _handle_data(self, endog, exog, missing, hasconst, **kwargs):
# --> 101         data = handle_data(endog, exog, missing, hasconst, **kwargs)
#     102         # kwargs arrays could have changed, easier to just attach here
#     103         for key in kwargs:
#
# D:\Anaconda3\lib\site-packages\statsmodels\base\data.py in handle_data(endog, exog, missing, hasconst, **kwargs)
#     670
#     671     klass = handle_data_class_factory(endog, exog)
# --> 672     return klass(endog, exog=exog, missing=missing, hasconst=hasconst,
#     673                  **kwargs)
#
# D:\Anaconda3\lib\site-packages\statsmodels\base\data.py in __init__(self, endog, exog, missing, hasconst, **kwargs)
#      85         self.const_idx = None
#      86         self.k_constant = 0
# ---> 87         self._handle_constant(hasconst)
#      88         self._check_integrity()
#      89         self._cache = {}
#
# D:\Anaconda3\lib\site-packages\statsmodels\base\data.py in _handle_constant(self, hasconst)
#     131             exog_max = np.max(self.exog, axis=0)
#     132             if not np.isfinite(exog_max).all():
# --> 133                 raise MissingDataError('exog contains inf or nans')
#     134             exog_min = np.min(self.exog, axis=0)
#     135             const_idx = np.where(exog_max == exog_min)[0].squeeze()
#
# MissingDataError: exog contains inf or nans

# %%
X_train, X_test, Y_train, Y_test = train_test_split(data, labels['nWBV'], test_size=0.1, random_state=255)
print(X_train.shape, Y_train.shape, X_test.shape, Y_test.shape)
# Out:
# (548, 3872) (548,) (61, 3872) (61,)

# %%
def RSS(y,Y):
    y = np.matrix(y).reshape(-1,1)
    Y = np.matrix(Y).reshape(-1,1)
    
    return (y-Y).T*(y-Y)

def RMS(y,Y):    
    return np.sqrt(RSS(y,Y))/len(y)

def Rs(y,Y): 
    y = np.matrix(y).reshape(-1,1)
    Y = np.matrix(Y).reshape(-1,1)
    
    return 1 - RSS(y,Y)/((Y - np.mean(Y)).T*(Y - Y.mean()))

# %%
ols = sm.OLS(Y_train, sm.add_constant(X_train))
ols_result = ols.fit()

ols_result.summary()
# Out:
# D:\Anaconda3\lib\site-packages\statsmodels\regression\linear_model.py:1728: RuntimeWarning: divide by zero encountered in true_divide
#   return 1 - (np.divide(self.nobs - self.k_constant, self.df_resid)
# D:\Anaconda3\lib\site-packages\statsmodels\regression\linear_model.py:1728: RuntimeWarning: invalid value encountered in double_scalars
#   return 1 - (np.divide(self.nobs - self.k_constant, self.df_resid)
# D:\Anaconda3\lib\site-packages\statsmodels\regression\linear_model.py:1650: RuntimeWarning: divide by zero encountered in double_scalars
#   return np.dot(wresid, wresid) / self.df_resid
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   nWBV   R-squared:                       1.000
# Model:                            OLS   Adj. R-squared:                    nan
# Method:                 Least Squares   F-statistic:                       nan
# Date:                Fri, 15 Oct 2021   Prob (F-statistic):                nan
# Time:                        01:11:37   Log-Likelihood:                 17459.
# No. Observations:                 548   AIC:                        -3.382e+04
# Df Residuals:                       0   BIC:                        -3.146e+04
# Df Model:                         547
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0130        inf         -0        nan         nan         nan
# x1             0.0016        inf          0        nan         nan         nan
# x2            -0.0031        inf         -0        nan         nan         nan
# x3            -0.0022        inf         -0        nan         nan         nan
# x4            -0.0036        inf         -0        nan         nan         nan
# x5            -0.0050        inf         -0        nan         nan         nan
# x6             0.0118        inf          0        nan         nan         nan
# x7            -0.0025        inf         -0        nan         nan         nan
# x8             0.0056        inf          0        nan         nan         nan
# x9             0.0063        inf          0        nan         nan         nan
# x10           -0.0085        inf         -0        nan         nan         nan
# x11           -0.0025        inf         -0        nan         nan         nan
# x12           -0.0035        inf         -0        nan         nan         nan
# x13           -0.0059        inf         -0        nan         nan         nan
# x14           -0.0037        inf         -0        nan         nan         nan
# x15           -0.0142        inf         -0        nan         nan         nan
# x16           -0.0101        inf         -0        nan         nan         nan
# x17           -0.0059        inf         -0        nan         nan         nan
# x18           -0.0039        inf         -0        nan         nan         nan
# x19           -0.0051        inf         -0        nan         nan         nan
# x20           -0.0038        inf         -0        nan         nan         nan
# x21           -0.0054        inf         -0        nan         nan         nan
# x22           -0.0051        inf         -0        nan         nan         nan
# x23           -0.0025        inf         -0        nan         nan         nan
# x24           -0.0032        inf         -0        nan         nan         nan
# x25            0.0009        inf          0        nan         nan         nan
# x26           -0.0006        inf         -0        nan         nan         nan
# x27            0.0148        inf          0        nan         nan         nan
# x28            0.0015        inf          0        nan         nan         nan
# x29           -0.0010        inf         -0        nan         nan         nan
# x30           -0.0005        inf         -0        nan         nan         nan
# x31           -0.0001        inf         -0        nan         nan         nan
# x32           -0.0023        inf         -0        nan         nan         nan
# x33            0.0032        inf          0        nan         nan         nan
# x34            0.0026        inf          0        nan         nan         nan
# x35           -0.0049        inf         -0        nan         nan         nan
# x36           -0.0006        inf         -0        nan         nan         nan
# x37           -0.0161        inf         -0        nan         nan         nan
# x38           -0.0072        inf         -0        nan         nan         nan
# x39           -0.0052        inf         -0        nan         nan         nan
# x40           -0.0044        inf         -0        nan         nan         nan
# x41           -0.0065        inf         -0        nan         nan         nan
# x42           -0.0038        inf         -0        nan         nan         nan
# x43           -0.0052        inf         -0        nan         nan         nan
# x44           -0.0049        inf         -0        nan         nan         nan
# x45           -0.0060        inf         -0        nan         nan         nan
# x46           -0.0096        inf         -0        nan         nan         nan
# x47           -0.0012        inf         -0        nan         nan         nan
# x48            0.0061        inf          0        nan         nan         nan
# x49            0.0142        inf          0        nan         nan         nan
# x50           -0.0040        inf         -0        nan         nan         nan
# x51           -0.0052        inf         -0        nan         nan         nan
# x52            0.0052        inf          0        nan         nan         nan
# x53        -8.229e-05        inf         -0        nan         nan         nan
# x54            0.0012        inf          0        nan         nan         nan
# x55            0.0301        inf          0        nan         nan         nan
# x56            0.0029        inf          0        nan         nan         nan
# x57           -0.0068        inf         -0        nan         nan         nan
# x58           -0.0087        inf         -0        nan         nan         nan
# x59           -0.0153        inf         -0        nan         nan         nan
# x60           -0.0004        inf         -0        nan         nan         nan
# x61           -0.0032        inf         -0        nan         nan         nan
# x62           -0.0062        inf         -0        nan         nan         nan
# x63           -0.0060        inf         -0        nan         nan         nan
# x64           -0.0040        inf         -0        nan         nan         nan
# x65           -0.0054        inf         -0        nan         nan         nan
# x66           -0.0053        inf         -0        nan         nan         nan
# x67           -0.0064        inf         -0        nan         nan         nan
# x68           -0.0123        inf         -0        nan         nan         nan
# x69            0.0015        inf          0        nan         nan         nan
# x70            0.0080        inf          0        nan         nan         nan
# x71            0.0147        inf          0        nan         nan         nan
# x72           -0.0025        inf         -0        nan         nan         nan
# x73           -0.0013        inf         -0        nan         nan         nan
# x74            0.0069        inf          0        nan         nan         nan
# x75           -0.0002        inf         -0        nan         nan         nan
# x76           -0.0024        inf         -0        nan         nan         nan
# x77            0.0111        inf          0        nan         nan         nan
# x78           -0.0010        inf         -0        nan         nan         nan
# x79        -2.527e-06        inf         -0        nan         nan         nan
# x80           -0.0011        inf         -0        nan         nan         nan
# x81           -0.0105        inf         -0        nan         nan         nan
# x82            0.0004        inf          0        nan         nan         nan
# x83           -0.0023        inf         -0        nan         nan         nan
# x84           -0.0045        inf         -0        nan         nan         nan
# x85           -0.0053        inf         -0        nan         nan         nan
# x86           -0.0049        inf         -0        nan         nan         nan
# x87           -0.0056        inf         -0        nan         nan         nan
# x88           -0.0054        inf         -0        nan         nan         nan
# x89           -0.0098        inf         -0        nan         nan         nan
# x90           -0.0088        inf         -0        nan         nan         nan
# x91           -0.0008        inf         -0        nan         nan         nan
# x92         2.207e-05        inf          0        nan         nan         nan
# x93            0.0111        inf          0        nan         nan         nan
# x94           -0.0035        inf         -0        nan         nan         nan
# x95            0.0020        inf          0        nan         nan         nan
# x96            0.0077        inf          0        nan         nan         nan
# x97            0.0068        inf          0        nan         nan         nan
# x98            0.0061        inf          0        nan         nan         nan
# x99            0.0027        inf          0        nan         nan         nan
# x100           0.0096        inf          0        nan         nan         nan
# x101          -0.0026        inf         -0        nan         nan         nan
# x102          -0.0009        inf         -0        nan         nan         nan
# x103          -0.0105        inf         -0        nan         nan         nan
# x104           0.0037        inf          0        nan         nan         nan
# x105          -0.0001        inf         -0        nan         nan         nan
# x106          -0.0043        inf         -0        nan         nan         nan
# x107          -0.0027        inf         -0        nan         nan         nan
# x108          -0.0009        inf         -0        nan         nan         nan
# x109          -0.0019        inf         -0        nan         nan         nan
# x110          -0.0044        inf         -0        nan         nan         nan
# x111          -0.0122        inf         -0        nan         nan         nan
# x112       -2.351e-05        inf         -0        nan         nan         nan
# x113          -0.0007        inf         -0        nan         nan         nan
# x114          -0.0092        inf         -0        nan         nan         nan
# x115           0.0154        inf          0        nan         nan         nan
# x116          -0.0029        inf         -0        nan         nan         nan
# x117           0.0053        inf          0        nan         nan         nan
# x118           0.0104        inf          0        nan         nan         nan
# x119          -0.0016        inf         -0        nan         nan         nan
# x120           0.0077        inf          0        nan         nan         nan
# x121          -0.0013        inf         -0        nan         nan         nan
# x122           0.0131        inf          0        nan         nan         nan
# x123          -0.0016        inf         -0        nan         nan         nan
# x124           0.0063        inf          0        nan         nan         nan
# x125          -0.0064        inf         -0        nan         nan         nan
# x126           0.0108        inf          0        nan         nan         nan
# x127           0.0034        inf          0        nan         nan         nan
# x128          -0.0047        inf         -0        nan         nan         nan
# x129           0.0012        inf          0        nan         nan         nan
# x130           0.0005        inf          0        nan         nan         nan
# x131           0.0004        inf          0        nan         nan         nan
# x132          -0.0040        inf         -0        nan         nan         nan
# x133          -0.0136        inf         -0        nan         nan         nan
# x134          -0.0005        inf         -0        nan         nan         nan
# x135           0.0060        inf          0        nan         nan         nan
# x136          -0.0073        inf         -0        nan         nan         nan
# x137           0.0120        inf          0        nan         nan         nan
# x138          -0.0024        inf         -0        nan         nan         nan
# x139           0.0082        inf          0        nan         nan         nan
# x140           0.0172        inf          0        nan         nan         nan
# x141           0.0072        inf          0        nan         nan         nan
# x142           0.0005        inf          0        nan         nan         nan
# x143           0.0017        inf          0        nan         nan         nan
# x144           0.0049        inf          0        nan         nan         nan
# x145           0.0061        inf          0        nan         nan         nan
# x146           0.0014        inf          0        nan         nan         nan
# x147           0.0066        inf          0        nan         nan         nan
# x148           0.0165        inf          0        nan         nan         nan
# x149           0.0020        inf          0        nan         nan         nan
# x150          -0.0080        inf         -0        nan         nan         nan
# x151           0.0014        inf          0        nan         nan         nan
# x152           0.0014        inf          0        nan         nan         nan
# x153           0.0022        inf          0        nan         nan         nan
# x154          -0.0047        inf         -0        nan         nan         nan
# x155          -0.0112        inf         -0        nan         nan         nan
# x156          -0.0007        inf         -0        nan         nan         nan
# x157           0.0086        inf          0        nan         nan         nan
# x158          -0.0136        inf         -0        nan         nan         nan
# x159           0.0073        inf          0        nan         nan         nan
# x160           0.0004        inf          0        nan         nan         nan
# x161           0.0116        inf          0        nan         nan         nan
# x162           0.0109        inf          0        nan         nan         nan
# x163           0.0036        inf          0        nan         nan         nan
# x164          -0.0073        inf         -0        nan         nan         nan
# x165          -0.0039        inf         -0        nan         nan         nan
# x166          -0.0062        inf         -0        nan         nan         nan
# x167           0.0051        inf          0        nan         nan         nan
# x168          -0.0064        inf         -0        nan         nan         nan
# x169           0.0346        inf          0        nan         nan         nan
# x170           0.0081        inf          0        nan         nan         nan
# x171          -0.0012        inf         -0        nan         nan         nan
# x172          -0.0063        inf         -0        nan         nan         nan
# x173           0.0005        inf          0        nan         nan         nan
# x174           0.0005        inf          0        nan         nan         nan
# x175           0.0018        inf          0        nan         nan         nan
# x176          -0.0038        inf         -0        nan         nan         nan
# x177          -0.0122        inf         -0        nan         nan         nan
# x178          -0.0001        inf         -0        nan         nan         nan
# x179           0.0096        inf          0        nan         nan         nan
# x180          -0.0077        inf         -0        nan         nan         nan
# x181          -0.0023        inf         -0        nan         nan         nan
# x182          -0.0023        inf         -0        nan         nan         nan
# x183           0.0116        inf          0        nan         nan         nan
# x184          -0.0016        inf         -0        nan         nan         nan
# x185           0.0198        inf          0        nan         nan         nan
# x186           0.0030        inf          0        nan         nan         nan
# x187           0.0288        inf          0        nan         nan         nan
# x188          -0.0066        inf         -0        nan         nan         nan
# x189          -0.0060        inf         -0        nan         nan         nan
# x190          -0.0067        inf         -0        nan         nan         nan
# x191           0.0341        inf          0        nan         nan         nan
# x192           0.0055        inf          0        nan         nan         nan
# x193          -0.0088        inf         -0        nan         nan         nan
# x194          -0.0050        inf         -0        nan         nan         nan
# x195          -0.0002        inf         -0        nan         nan         nan
# x196          -0.0037        inf         -0        nan         nan         nan
# x197          -0.0033        inf         -0        nan         nan         nan
# x198          -0.0040        inf         -0        nan         nan         nan
# x199          -0.0080        inf         -0        nan         nan         nan
# x200          -0.0016        inf         -0        nan         nan         nan
# x201           0.0113        inf          0        nan         nan         nan
# x202          -0.0025        inf         -0        nan         nan         nan
# x203          -0.0133        inf         -0        nan         nan         nan
# x204          -0.0174        inf         -0        nan         nan         nan
# x205          -0.0043        inf         -0        nan         nan         nan
# x206          -0.0136        inf         -0        nan         nan         nan
# x207          -0.0025        inf         -0        nan         nan         nan
# x208           0.0065        inf          0        nan         nan         nan
# x209           0.0275        inf          0        nan         nan         nan
# x210           0.0190        inf          0        nan         nan         nan
# x211          -0.0157        inf         -0        nan         nan         nan
# x212          -0.0064        inf         -0        nan         nan         nan
# x213           0.0227        inf          0        nan         nan         nan
# x214          -0.0040        inf         -0        nan         nan         nan
# x215          -0.0075        inf         -0        nan         nan         nan
# x216          -0.0055        inf         -0        nan         nan         nan
# x217          -0.0041        inf         -0        nan         nan         nan
# x218          -0.0041        inf         -0        nan         nan         nan
# x219          -0.0044        inf         -0        nan         nan         nan
# x220          -0.0048        inf         -0        nan         nan         nan
# x221          -0.0066        inf         -0        nan         nan         nan
# x222           0.0039        inf          0        nan         nan         nan
# x223           0.0017        inf          0        nan         nan         nan
# x224           0.0073        inf          0        nan         nan         nan
# x225          -0.0100        inf         -0        nan         nan         nan
# x226          -0.0157        inf         -0        nan         nan         nan
# x227          -0.0004        inf         -0        nan         nan         nan
# x228          -0.0018        inf         -0        nan         nan         nan
# x229          -0.0002        inf         -0        nan         nan         nan
# x230           0.0072        inf          0        nan         nan         nan
# x231           0.0173        inf          0        nan         nan         nan
# x232           0.0274        inf          0        nan         nan         nan
# x233          -0.0036        inf         -0        nan         nan         nan
# x234          -0.0111        inf         -0        nan         nan         nan
# x235           0.0097        inf          0        nan         nan         nan
# x236          -0.0013        inf         -0        nan         nan         nan
# x237          -0.0008        inf         -0        nan         nan         nan
# x238          -0.0034        inf         -0        nan         nan         nan
# x239          -0.0035        inf         -0        nan         nan         nan
# x240          -0.0031        inf         -0        nan         nan         nan
# x241          -0.0043        inf         -0        nan         nan         nan
# x242          -0.0034        inf         -0        nan         nan         nan
# x243          -0.0053        inf         -0        nan         nan         nan
# x244           0.0067        inf          0        nan         nan         nan
# x245          -0.0012        inf         -0        nan         nan         nan
# x246           0.0015        inf          0        nan         nan         nan
# x247           0.0008        inf          0        nan         nan         nan
# x248          -0.0049        inf         -0        nan         nan         nan
# x249           0.0006        inf          0        nan         nan         nan
# x250           0.0036        inf          0        nan         nan         nan
# x251          -0.0026        inf         -0        nan         nan         nan
# x252          -0.0081        inf         -0        nan         nan         nan
# x253           0.0104        inf          0        nan         nan         nan
# x254           0.0110        inf          0        nan         nan         nan
# x255           0.0286        inf          0        nan         nan         nan
# x256          -0.0106        inf         -0        nan         nan         nan
# x257          -0.0097        inf         -0        nan         nan         nan
# x258           0.0015        inf          0        nan         nan         nan
# x259           0.0015        inf          0        nan         nan         nan
# x260           0.0036        inf          0        nan         nan         nan
# x261          -0.0025        inf         -0        nan         nan         nan
# x262          -0.0023        inf         -0        nan         nan         nan
# x263          -0.0038        inf         -0        nan         nan         nan
# x264          -0.0011        inf         -0        nan         nan         nan
# x265           0.0034        inf          0        nan         nan         nan
# x266           0.0125        inf          0        nan         nan         nan
# x267           0.0023        inf          0        nan         nan         nan
# x268          -0.0044        inf         -0        nan         nan         nan
# x269           0.0004        inf          0        nan         nan         nan
# x270          -0.0030        inf         -0        nan         nan         nan
# x271           0.0016        inf          0        nan         nan         nan
# x272           0.0124        inf          0        nan         nan         nan
# x273          -0.0059        inf         -0        nan         nan         nan
# x274          -0.0131        inf         -0        nan         nan         nan
# x275           0.0117        inf          0        nan         nan         nan
# x276           0.0073        inf          0        nan         nan         nan
# x277          -0.0033        inf         -0        nan         nan         nan
# x278          -0.0190        inf         -0        nan         nan         nan
# x279          -0.0099        inf         -0        nan         nan         nan
# x280          -0.0010        inf         -0        nan         nan         nan
# x281           0.0086        inf          0        nan         nan         nan
# x282           0.0069        inf          0        nan         nan         nan
# x283           0.0048        inf          0        nan         nan         nan
# x284          -0.0014        inf         -0        nan         nan         nan
# x285          -0.0019        inf         -0        nan         nan         nan
# x286           0.0008        inf          0        nan         nan         nan
# x287           0.0087        inf          0        nan         nan         nan
# x288           0.0083        inf          0        nan         nan         nan
# x289          -0.0143        inf         -0        nan         nan         nan
# x290           0.0046        inf          0        nan         nan         nan
# x291           0.0047        inf          0        nan         nan         nan
# x292          -0.0096        inf         -0        nan         nan         nan
# x293          -0.0178        inf         -0        nan         nan         nan
# x294           0.0199        inf          0        nan         nan         nan
# x295           0.0111        inf          0        nan         nan         nan
# x296          -0.0137        inf         -0        nan         nan         nan
# x297          -0.0083        inf         -0        nan         nan         nan
# x298           0.0001        inf          0        nan         nan         nan
# x299           0.0216        inf          0        nan         nan         nan
# x300          -0.0146        inf         -0        nan         nan         nan
# x301           0.0050        inf          0        nan         nan         nan
# x302           0.0024        inf          0        nan         nan         nan
# x303           0.0125        inf          0        nan         nan         nan
# x304           0.0032        inf          0        nan         nan         nan
# x305           0.0016        inf          0        nan         nan         nan
# x306           0.0019        inf          0        nan         nan         nan
# x307          -0.0011        inf         -0        nan         nan         nan
# x308           0.0018        inf          0        nan         nan         nan
# x309           0.0039        inf          0        nan         nan         nan
# x310           0.0067        inf          0        nan         nan         nan
# x311          -0.0198        inf         -0        nan         nan         nan
# x312          -0.0009        inf         -0        nan         nan         nan
# x313          -0.0020        inf         -0        nan         nan         nan
# x314          -0.0210        inf         -0        nan         nan         nan
# x315          -0.0033        inf         -0        nan         nan         nan
# x316           0.0159        inf          0        nan         nan         nan
# x317           0.0174        inf          0        nan         nan         nan
# x318           0.0069        inf          0        nan         nan         nan
# x319          -0.0098        inf         -0        nan         nan         nan
# x320          -0.0060        inf         -0        nan         nan         nan
# x321           0.0259        inf          0        nan         nan         nan
# x322          -0.0278        inf         -0        nan         nan         nan
# x323           0.0165        inf          0        nan         nan         nan
# x324          -0.0076        inf         -0        nan         nan         nan
# x325           0.0094        inf          0        nan         nan         nan
# x326          -0.0037        inf         -0        nan         nan         nan
# x327          -0.0027        inf         -0        nan         nan         nan
# x328           0.0055        inf          0        nan         nan         nan
# x329          -0.0015        inf         -0        nan         nan         nan
# x330           0.0013        inf          0        nan         nan         nan
# x331           0.0023        inf          0        nan         nan         nan
# x332           0.0078        inf          0        nan         nan         nan
# x333           0.0238        inf          0        nan         nan         nan
# x334           0.0003        inf          0        nan         nan         nan
# x335          -0.0174        inf         -0        nan         nan         nan
# x336          -0.0077        inf         -0        nan         nan         nan
# x337          -0.0140        inf         -0        nan         nan         nan
# x338           0.0122        inf          0        nan         nan         nan
# x339           0.0098        inf          0        nan         nan         nan
# x340           0.0102        inf          0        nan         nan         nan
# x341          -0.0007        inf         -0        nan         nan         nan
# x342           0.0002        inf          0        nan         nan         nan
# x343           0.0009        inf          0        nan         nan         nan
# x344           0.0004        inf          0        nan         nan         nan
# x345          -0.0090        inf         -0        nan         nan         nan
# x346          -0.0073        inf         -0        nan         nan         nan
# x347           0.0084        inf          0        nan         nan         nan
# x348          -0.0019        inf         -0        nan         nan         nan
# x349          -0.0012        inf         -0        nan         nan         nan
# x350           0.0050        inf          0        nan         nan         nan
# x351          -0.0044        inf         -0        nan         nan         nan
# x352           0.0025        inf          0        nan         nan         nan
# x353           0.0113        inf          0        nan         nan         nan
# x354           0.0055        inf          0        nan         nan         nan
# x355           0.0245        inf          0        nan         nan         nan
# x356          -0.0219        inf         -0        nan         nan         nan
# x357          -0.0203        inf         -0        nan         nan         nan
# x358          -0.0266        inf         -0        nan         nan         nan
# x359          -0.0043        inf         -0        nan         nan         nan
# x360           0.0225        inf          0        nan         nan         nan
# x361          -0.0047        inf         -0        nan         nan         nan
# x362           0.0193        inf          0        nan         nan         nan
# x363          -0.0074        inf         -0        nan         nan         nan
# x364          -0.0053        inf         -0        nan         nan         nan
# x365          -0.0090        inf         -0        nan         nan         nan
# x366           0.0196        inf          0        nan         nan         nan
# x367          -0.0099        inf         -0        nan         nan         nan
# x368          -0.0055        inf         -0        nan         nan         nan
# x369           0.0056        inf          0        nan         nan         nan
# x370          -0.0075        inf         -0        nan         nan         nan
# x371          -0.0022        inf         -0        nan         nan         nan
# x372          -0.0008        inf         -0        nan         nan         nan
# x373          -0.0044        inf         -0        nan         nan         nan
# x374           0.0010        inf          0        nan         nan         nan
# x375           0.0044        inf          0        nan         nan         nan
# x376           0.0012        inf          0        nan         nan         nan
# x377           0.0210        inf          0        nan         nan         nan
# x378          -0.0070        inf         -0        nan         nan         nan
# x379           0.0048        inf          0        nan         nan         nan
# x380          -0.0215        inf         -0        nan         nan         nan
# x381           0.0193        inf          0        nan         nan         nan
# x382           0.0070        inf          0        nan         nan         nan
# x383           0.0233        inf          0        nan         nan         nan
# x384           0.0187        inf          0        nan         nan         nan
# x385          -0.0090        inf         -0        nan         nan         nan
# x386          -0.0028        inf         -0        nan         nan         nan
# x387           0.0030        inf          0        nan         nan         nan
# x388           0.0028        inf          0        nan         nan         nan
# x389          -0.0003        inf         -0        nan         nan         nan
# x390           0.0136        inf          0        nan         nan         nan
# x391           0.0009        inf          0        nan         nan         nan
# x392          -0.0028        inf         -0        nan         nan         nan
# x393          -0.0032        inf         -0        nan         nan         nan
# x394          -0.0013        inf         -0        nan         nan         nan
# x395          -0.0025        inf         -0        nan         nan         nan
# x396          -0.0019        inf         -0        nan         nan         nan
# x397          -0.0188        inf         -0        nan         nan         nan
# x398          -0.0047        inf         -0        nan         nan         nan
# x399           0.0084        inf          0        nan         nan         nan
# x400           0.0221        inf          0        nan         nan         nan
# x401           0.0049        inf          0        nan         nan         nan
# x402          -0.0099        inf         -0        nan         nan         nan
# x403           0.0068        inf          0        nan         nan         nan
# x404           0.0038        inf          0        nan         nan         nan
# x405           0.0363        inf          0        nan         nan         nan
# x406           0.0049        inf          0        nan         nan         nan
# x407          -0.0227        inf         -0        nan         nan         nan
# x408          -0.0244        inf         -0        nan         nan         nan
# x409           0.0230        inf          0        nan         nan         nan
# x410           0.0041        inf          0        nan         nan         nan
# x411           0.0211        inf          0        nan         nan         nan
# x412       -3.752e-05        inf         -0        nan         nan         nan
# x413          -0.0046        inf         -0        nan         nan         nan
# x414           0.0009        inf          0        nan         nan         nan
# x415          -0.0036        inf         -0        nan         nan         nan
# x416          -0.0016        inf         -0        nan         nan         nan
# x417          -0.0021        inf         -0        nan         nan         nan
# x418          -0.0007        inf         -0        nan         nan         nan
# x419          -0.0251        inf         -0        nan         nan         nan
# x420          -0.0092        inf         -0        nan         nan         nan
# x421           0.0031        inf          0        nan         nan         nan
# x422           0.0098        inf          0        nan         nan         nan
# x423           0.0012        inf          0        nan         nan         nan
# x424           0.0065        inf          0        nan         nan         nan
# x425           0.0139        inf          0        nan         nan         nan
# x426           0.0098        inf          0        nan         nan         nan
# x427           0.0008        inf          0        nan         nan         nan
# x428           0.0016        inf          0        nan         nan         nan
# x429           0.0009        inf          0        nan         nan         nan
# x430          -0.0097        inf         -0        nan         nan         nan
# x431           0.0143        inf          0        nan         nan         nan
# x432           0.0016        inf          0        nan         nan         nan
# x433           0.0038        inf          0        nan         nan         nan
# x434           0.0149        inf          0        nan         nan         nan
# x435          -0.0047        inf         -0        nan         nan         nan
# x436          -0.0025        inf         -0        nan         nan         nan
# x437          -0.0095        inf         -0        nan         nan         nan
# x438           0.0023        inf          0        nan         nan         nan
# x439          -0.0012        inf         -0        nan         nan         nan
# x440          -0.0017        inf         -0        nan         nan         nan
# x441          -0.0072        inf         -0        nan         nan         nan
# x442           0.0018        inf          0        nan         nan         nan
# x443           0.0095        inf          0        nan         nan         nan
# x444           0.0006        inf          0        nan         nan         nan
# x445           0.0108        inf          0        nan         nan         nan
# x446          -0.0323        inf         -0        nan         nan         nan
# x447           0.0043        inf          0        nan         nan         nan
# x448           0.0038        inf          0        nan         nan         nan
# x449          -0.0003        inf         -0        nan         nan         nan
# x450           0.0022        inf          0        nan         nan         nan
# x451           0.0131        inf          0        nan         nan         nan
# x452           0.0017        inf          0        nan         nan         nan
# x453           0.0182        inf          0        nan         nan         nan
# x454           0.0217        inf          0        nan         nan         nan
# x455           0.0023        inf          0        nan         nan         nan
# x456           0.0071        inf          0        nan         nan         nan
# x457           0.0093        inf          0        nan         nan         nan
# x458           0.0071        inf          0        nan         nan         nan
# x459          -0.0037        inf         -0        nan         nan         nan
# x460           0.0005        inf          0        nan         nan         nan
# x461           0.0006        inf          0        nan         nan         nan
# x462          -0.0020        inf         -0        nan         nan         nan
# x463          -0.0030        inf         -0        nan         nan         nan
# x464          -0.0101        inf         -0        nan         nan         nan
# x465          -0.0062        inf         -0        nan         nan         nan
# x466          -0.0067        inf         -0        nan         nan         nan
# x467          -0.0065        inf         -0        nan         nan         nan
# x468          -0.0236        inf         -0        nan         nan         nan
# x469           0.0103        inf          0        nan         nan         nan
# x470           0.0022        inf          0        nan         nan         nan
# x471           0.0213        inf          0        nan         nan         nan
# x472           0.0167        inf          0        nan         nan         nan
# x473          -0.0080        inf         -0        nan         nan         nan
# x474           0.0050        inf          0        nan         nan         nan
# x475           0.0220        inf          0        nan         nan         nan
# x476           0.0354        inf          0        nan         nan         nan
# x477           0.0215        inf          0        nan         nan         nan
# x478          -0.0159        inf         -0        nan         nan         nan
# x479          -0.0068        inf         -0        nan         nan         nan
# x480           0.0129        inf          0        nan         nan         nan
# x481           0.0021        inf          0        nan         nan         nan
# x482          -0.0031        inf         -0        nan         nan         nan
# x483           0.0062        inf          0        nan         nan         nan
# x484          -0.0027        inf         -0        nan         nan         nan
# x485          -0.0157        inf         -0        nan         nan         nan
# x486          -0.0085        inf         -0        nan         nan         nan
# x487          -0.0123        inf         -0        nan         nan         nan
# x488          -0.0262        inf         -0        nan         nan         nan
# x489          -0.0101        inf         -0        nan         nan         nan
# x490          -0.0066        inf         -0        nan         nan         nan
# x491           0.0054        inf          0        nan         nan         nan
# x492           0.0139        inf          0        nan         nan         nan
# x493           0.0314        inf          0        nan         nan         nan
# x494          -0.0045        inf         -0        nan         nan         nan
# x495          -0.0010        inf         -0        nan         nan         nan
# x496          -0.0078        inf         -0        nan         nan         nan
# x497           0.0353        inf          0        nan         nan         nan
# x498           0.0162        inf          0        nan         nan         nan
# x499           0.0252        inf          0        nan         nan         nan
# x500          -0.0068        inf         -0        nan         nan         nan
# x501          -0.0087        inf         -0        nan         nan         nan
# x502           0.0114        inf          0        nan         nan         nan
# x503           0.0026        inf          0        nan         nan         nan
# x504          -0.0054        inf         -0        nan         nan         nan
# x505           0.0031        inf          0        nan         nan         nan
# x506          -0.0013        inf         -0        nan         nan         nan
# x507          -0.0061        inf         -0        nan         nan         nan
# x508           0.0175        inf          0        nan         nan         nan
# x509           0.0126        inf          0        nan         nan         nan
# x510          -0.0178        inf         -0        nan         nan         nan
# x511          -0.0158        inf         -0        nan         nan         nan
# x512           0.0028        inf          0        nan         nan         nan
# x513           0.0044        inf          0        nan         nan         nan
# x514           0.0140        inf          0        nan         nan         nan
# x515           0.0155        inf          0        nan         nan         nan
# x516          -0.0257        inf         -0        nan         nan         nan
# x517          -0.0197        inf         -0        nan         nan         nan
# x518           0.0183        inf          0        nan         nan         nan
# x519           0.0166        inf          0        nan         nan         nan
# x520           0.0056        inf          0        nan         nan         nan
# x521           0.0175        inf          0        nan         nan         nan
# x522          -0.0012        inf         -0        nan         nan         nan
# x523           0.0131        inf          0        nan         nan         nan
# x524           0.0041        inf          0        nan         nan         nan
# x525        2.901e-05        inf          0        nan         nan         nan
# x526          -0.0020        inf         -0        nan         nan         nan
# x527           0.0004        inf          0        nan         nan         nan
# x528          -0.0027        inf         -0        nan         nan         nan
# x529           0.0074        inf          0        nan         nan         nan
# x530           0.0231        inf          0        nan         nan         nan
# x531           0.0244        inf          0        nan         nan         nan
# x532           0.0002        inf          0        nan         nan         nan
# x533           0.0135        inf          0        nan         nan         nan
# x534           0.0182        inf          0        nan         nan         nan
# x535          -0.0026        inf         -0        nan         nan         nan
# x536           0.0220        inf          0        nan         nan         nan
# x537           0.0152        inf          0        nan         nan         nan
# x538          -0.0018        inf         -0        nan         nan         nan
# x539          -0.0137        inf         -0        nan         nan         nan
# x540          -0.0005        inf         -0        nan         nan         nan
# x541           0.0157        inf          0        nan         nan         nan
# x542           0.0172        inf          0        nan         nan         nan
# x543           0.0038        inf          0        nan         nan         nan
# x544           0.0165        inf          0        nan         nan         nan
# x545           0.0232        inf          0        nan         nan         nan
# x546           0.0041        inf          0        nan         nan         nan
# x547           0.0008        inf          0        nan         nan         nan
# x548          -0.0044        inf         -0        nan         nan         nan
# x549           0.0002        inf          0        nan         nan         nan
# x550          -0.0029        inf         -0        nan         nan         nan
# x551           0.0062        inf          0        nan         nan         nan
# x552           0.0222        inf          0        nan         nan         nan
# x553           0.0043        inf          0        nan         nan         nan
# x554           0.0148        inf          0        nan         nan         nan
# x555           0.0064        inf          0        nan         nan         nan
# x556          -0.0040        inf         -0        nan         nan         nan
# x557          -0.0037        inf         -0        nan         nan         nan
# x558           0.0190        inf          0        nan         nan         nan
# x559           0.0244        inf          0        nan         nan         nan
# x560          -0.0019        inf         -0        nan         nan         nan
# x561          -0.0078        inf         -0        nan         nan         nan
# x562          -0.0089        inf         -0        nan         nan         nan
# x563          -0.0233        inf         -0        nan         nan         nan
# x564           0.0090        inf          0        nan         nan         nan
# x565          -0.0089        inf         -0        nan         nan         nan
# x566           0.0062        inf          0        nan         nan         nan
# x567          -0.0066        inf         -0        nan         nan         nan
# x568          -0.0031        inf         -0        nan         nan         nan
# x569           0.0014        inf          0        nan         nan         nan
# x570          -0.0084        inf         -0        nan         nan         nan
# x571          -0.0004        inf         -0        nan         nan         nan
# x572          -0.0028        inf         -0        nan         nan         nan
# x573           0.0054        inf          0        nan         nan         nan
# x574           0.0063        inf          0        nan         nan         nan
# x575           0.0014        inf          0        nan         nan         nan
# x576           0.0151        inf          0        nan         nan         nan
# x577          -0.0084        inf         -0        nan         nan         nan
# x578          -0.0172        inf         -0        nan         nan         nan
# x579           0.0066        inf          0        nan         nan         nan
# x580           0.0019        inf          0        nan         nan         nan
# x581           0.0076        inf          0        nan         nan         nan
# x582          -0.0127        inf         -0        nan         nan         nan
# x583          -0.0104        inf         -0        nan         nan         nan
# x584           0.0125        inf          0        nan         nan         nan
# ...
# x3681         -0.0083        inf         -0        nan         nan         nan
# x3682         -0.0019        inf         -0        nan         nan         nan
# x3683         -0.0141        inf         -0        nan         nan         nan
# x3684         -0.0103        inf         -0        nan         nan         nan
# x3685          0.0204        inf          0        nan         nan         nan
# x3686          0.0186        inf          0        nan         nan         nan
# x3687         -0.0009        inf         -0        nan         nan         nan
# x3688          0.0017        inf          0        nan         nan         nan
# x3689          0.0061        inf          0        nan         nan         nan
# x3690         -0.0073        inf         -0        nan         nan         nan
# x3691          0.0027        inf          0        nan         nan         nan
# x3692         -0.0001        inf         -0        nan         nan         nan
# x3693         -0.0037        inf         -0        nan         nan         nan
# x3694         -0.0008        inf         -0        nan         nan         nan
# x3695         -0.0035        inf         -0        nan         nan         nan
# x3696         -0.0031        inf         -0        nan         nan         nan
# x3697         -0.0029        inf         -0        nan         nan         nan
# x3698         -0.0051        inf         -0        nan         nan         nan
# x3699         -0.0019        inf         -0        nan         nan         nan
# x3700          0.0031        inf          0        nan         nan         nan
# x3701          0.0122        inf          0        nan         nan         nan
# x3702         -0.0101        inf         -0        nan         nan         nan
# x3703         -0.0039        inf         -0        nan         nan         nan
# x3704         -0.0086        inf         -0        nan         nan         nan
# x3705         -0.0056        inf         -0        nan         nan         nan
# x3706         -0.0087        inf         -0        nan         nan         nan
# x3707          0.0065        inf          0        nan         nan         nan
# x3708      -2.606e-05        inf         -0        nan         nan         nan
# x3709         -0.0037        inf         -0        nan         nan         nan
# x3710          0.0029        inf          0        nan         nan         nan
# x3711          0.0002        inf          0        nan         nan         nan
# x3712         -0.0111        inf         -0        nan         nan         nan
# x3713          0.0015        inf          0        nan         nan         nan
# x3714         -0.0005        inf         -0        nan         nan         nan
# x3715         -0.0046        inf         -0        nan         nan         nan
# x3716         -0.0026        inf         -0        nan         nan         nan
# x3717         -0.0026        inf         -0        nan         nan         nan
# x3718         -0.0036        inf         -0        nan         nan         nan
# x3719         -0.0047        inf         -0        nan         nan         nan
# x3720         -0.0060        inf         -0        nan         nan         nan
# x3721          0.0002        inf          0        nan         nan         nan
# x3722         -0.0042        inf         -0        nan         nan         nan
# x3723          0.0107        inf          0        nan         nan         nan
# x3724         -0.0056        inf         -0        nan         nan         nan
# x3725          0.0029        inf          0        nan         nan         nan
# x3726         -0.0085        inf         -0        nan         nan         nan
# x3727          0.0010        inf          0        nan         nan         nan
# x3728         -0.0013        inf         -0        nan         nan         nan
# x3729          0.0068        inf          0        nan         nan         nan
# x3730          0.0125        inf          0        nan         nan         nan
# x3731         -0.0014        inf         -0        nan         nan         nan
# x3732         -0.0026        inf         -0        nan         nan         nan
# x3733          0.0045        inf          0        nan         nan         nan
# x3734         -0.0017        inf         -0        nan         nan         nan
# x3735          0.0023        inf          0        nan         nan         nan
# x3736         -0.0023        inf         -0        nan         nan         nan
# x3737         -0.0051        inf         -0        nan         nan         nan
# x3738         -0.0077        inf         -0        nan         nan         nan
# x3739         -0.0044        inf         -0        nan         nan         nan
# x3740         -0.0034        inf         -0        nan         nan         nan
# x3741         -0.0028        inf         -0        nan         nan         nan
# x3742         -0.0041        inf         -0        nan         nan         nan
# x3743         -0.0007        inf         -0        nan         nan         nan
# x3744       9.007e-05        inf          0        nan         nan         nan
# x3745          0.0091        inf          0        nan         nan         nan
# x3746         -0.0016        inf         -0        nan         nan         nan
# x3747          0.0028        inf          0        nan         nan         nan
# x3748         -0.0123        inf         -0        nan         nan         nan
# x3749          0.0022        inf          0        nan         nan         nan
# x3750         -0.0030        inf         -0        nan         nan         nan
# x3751          0.0066        inf          0        nan         nan         nan
# x3752          0.0157        inf          0        nan         nan         nan
# x3753         -0.0046        inf         -0        nan         nan         nan
# x3754          0.0024        inf          0        nan         nan         nan
# x3755         -0.0023        inf         -0        nan         nan         nan
# x3756         -0.0018        inf         -0        nan         nan         nan
# x3757          0.0029        inf          0        nan         nan         nan
# x3758         -0.0034        inf         -0        nan         nan         nan
# x3759         -0.0050        inf         -0        nan         nan         nan
# x3760         -0.0078        inf         -0        nan         nan         nan
# x3761         -0.0054        inf         -0        nan         nan         nan
# x3762         -0.0040        inf         -0        nan         nan         nan
# x3763         -0.0040        inf         -0        nan         nan         nan
# x3764         -0.0053        inf         -0        nan         nan         nan
# x3765         -0.0015        inf         -0        nan         nan         nan
# x3766         -0.0015        inf         -0        nan         nan         nan
# x3767          0.0067        inf          0        nan         nan         nan
# x3768          0.0034        inf          0        nan         nan         nan
# x3769          0.0041        inf          0        nan         nan         nan
# x3770         -0.0091        inf         -0        nan         nan         nan
# x3771          0.0032        inf          0        nan         nan         nan
# x3772         -0.0032        inf         -0        nan         nan         nan
# x3773          0.0086        inf          0        nan         nan         nan
# x3774          0.0135        inf          0        nan         nan         nan
# x3775         -0.0089        inf         -0        nan         nan         nan
# x3776          0.0062        inf          0        nan         nan         nan
# x3777         -0.0016        inf         -0        nan         nan         nan
# x3778          0.0001        inf          0        nan         nan         nan
# x3779          0.0022        inf          0        nan         nan         nan
# x3780         -0.0032        inf         -0        nan         nan         nan
# x3781         -0.0048        inf         -0        nan         nan         nan
# x3782         -0.0075        inf         -0        nan         nan         nan
# x3783         -0.0052        inf         -0        nan         nan         nan
# x3784         -0.0051        inf         -0        nan         nan         nan
# x3785         -0.0042        inf         -0        nan         nan         nan
# x3786         -0.0063        inf         -0        nan         nan         nan
# x3787         -0.0036        inf         -0        nan         nan         nan
# x3788         -0.0013        inf         -0        nan         nan         nan
# x3789         -0.0031        inf         -0        nan         nan         nan
# x3790          0.0062        inf          0        nan         nan         nan
# x3791         -0.0005        inf         -0        nan         nan         nan
# x3792         -0.0030        inf         -0        nan         nan         nan
# x3793          0.0032        inf          0        nan         nan         nan
# x3794          0.0002        inf          0        nan         nan         nan
# x3795          0.0036        inf          0        nan         nan         nan
# x3796          0.0119        inf          0        nan         nan         nan
# x3797         -0.0037        inf         -0        nan         nan         nan
# x3798          0.0066        inf          0        nan         nan         nan
# x3799         -0.0021        inf         -0        nan         nan         nan
# x3800         -0.0043        inf         -0        nan         nan         nan
# x3801          0.0004        inf          0        nan         nan         nan
# x3802         -0.0037        inf         -0        nan         nan         nan
# x3803         -0.0051        inf         -0        nan         nan         nan
# x3804         -0.0065        inf         -0        nan         nan         nan
# x3805         -0.0050        inf         -0        nan         nan         nan
# x3806         -0.0055        inf         -0        nan         nan         nan
# x3807         -0.0024        inf         -0        nan         nan         nan
# x3808         -0.0053        inf         -0        nan         nan         nan
# x3809         -0.0035        inf         -0        nan         nan         nan
# x3810         -0.0017        inf         -0        nan         nan         nan
# x3811         -0.0032        inf         -0        nan         nan         nan
# x3812          0.0038        inf          0        nan         nan         nan
# x3813         -0.0073        inf         -0        nan         nan         nan
# x3814         -0.0031        inf         -0        nan         nan         nan
# x3815          0.0013        inf          0        nan         nan         nan
# x3816          0.0044        inf          0        nan         nan         nan
# x3817          0.0055        inf          0        nan         nan         nan
# x3818          0.0107        inf          0        nan         nan         nan
# x3819          0.0033        inf          0        nan         nan         nan
# x3820          0.0052        inf          0        nan         nan         nan
# x3821         -0.0041        inf         -0        nan         nan         nan
# x3822         -0.0045        inf         -0        nan         nan         nan
# x3823      -7.424e-06        inf         -0        nan         nan         nan
# x3824         -0.0040        inf         -0        nan         nan         nan
# x3825         -0.0064        inf         -0        nan         nan         nan
# x3826         -0.0068        inf         -0        nan         nan         nan
# x3827         -0.0054        inf         -0        nan         nan         nan
# x3828         -0.0063        inf         -0        nan         nan         nan
# x3829         -0.0027        inf         -0        nan         nan         nan
# x3830         -0.0047        inf         -0        nan         nan         nan
# x3831         -0.0041        inf         -0        nan         nan         nan
# x3832         -0.0021        inf         -0        nan         nan         nan
# x3833         -0.0024        inf         -0        nan         nan         nan
# x3834          0.0043        inf          0        nan         nan         nan
# x3835          0.0021        inf          0        nan         nan         nan
# x3836         -0.0070        inf         -0        nan         nan         nan
# x3837         -0.0019        inf         -0        nan         nan         nan
# x3838          0.0029        inf          0        nan         nan         nan
# x3839          0.0036        inf          0        nan         nan         nan
# x3840          0.0023        inf          0        nan         nan         nan
# x3841          0.0021        inf          0        nan         nan         nan
# x3842          0.0020        inf          0        nan         nan         nan
# x3843         -0.0033        inf         -0        nan         nan         nan
# x3844         -0.0023        inf         -0        nan         nan         nan
# x3845         -0.0011        inf         -0        nan         nan         nan
# x3846         -0.0051        inf         -0        nan         nan         nan
# x3847         -0.0064        inf         -0        nan         nan         nan
# x3848         -0.0068        inf         -0        nan         nan         nan
# x3849         -0.0065        inf         -0        nan         nan         nan
# x3850         -0.0077        inf         -0        nan         nan         nan
# x3851         -0.0051        inf         -0        nan         nan         nan
# x3852         -0.0045        inf         -0        nan         nan         nan
# x3853         -0.0039        inf         -0        nan         nan         nan
# x3854         -0.0048        inf         -0        nan         nan         nan
# x3855         -0.0034        inf         -0        nan         nan         nan
# x3856          0.0030        inf          0        nan         nan         nan
# x3857          0.0028        inf          0        nan         nan         nan
# x3858         -0.0012        inf         -0        nan         nan         nan
# x3859          0.0023        inf          0        nan         nan         nan
# x3860          0.0006        inf          0        nan         nan         nan
# x3861          0.0020        inf          0        nan         nan         nan
# x3862          0.0043        inf          0        nan         nan         nan
# x3863          0.0019        inf          0        nan         nan         nan
# x3864          0.0008        inf          0        nan         nan         nan
# x3865         -0.0043        inf         -0        nan         nan         nan
# x3866         -0.0011        inf         -0        nan         nan         nan
# x3867         -0.0030        inf         -0        nan         nan         nan
# x3868         -0.0061        inf         -0        nan         nan         nan
# x3869         -0.0076        inf         -0        nan         nan         nan
# x3870         -0.0078        inf         -0        nan         nan         nan
# x3871         -0.0082        inf         -0        nan         nan         nan
# x3872         -0.0084        inf         -0        nan         nan         nan
# ==============================================================================
# Omnibus:                      395.240   Durbin-Watson:                   0.206
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            17119.418
# Skew:                          -2.617   Prob(JB):                         0.00
# Kurtosis:                      29.877   Cond. No.                     1.75e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The input rank is higher than the number of observations.
# [3] The condition number is large, 1.75e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
pred = ols_result.predict(sm.add_constant(X_test))
#Rs(pred, Y_test)
RMS(pred,Y_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-22-f275ee31acd6> in <module>
# ----> 1 pred = ols_result.predict(sm.add_constant(X_test))
#       2 #Rs(pred, Y_test)
#       3 RMS(pred,Y_test)
#
# D:\Anaconda3\lib\site-packages\statsmodels\base\model.py in predict(self, exog, transform, *args, **kwargs)
#    1097             exog = np.atleast_2d(exog)  # needed in count model shape[1]
#    1098
# -> 1099         predict_results = self.model.predict(self.params, exog, *args,
#    1100                                              **kwargs)
#    1101
#
# D:\Anaconda3\lib\site-packages\statsmodels\regression\linear_model.py in predict(self, params, exog)
#     378             exog = self.exog
#     379
# --> 380         return np.dot(exog, params)
#     381
#     382     def get_distribution(self, params, scale, exog=None, dist_class=None):
#
# <__array_function__ internals> in dot(*args, **kwargs)
#
# ValueError: shapes (61,3872) and (3873,) not aligned: 3872 (dim 1) != 3873 (dim 0)

# %% [markdown]
# When I printed the shape of X_train & X_test, both had 3872 value, but while fitting into the ols model, it says their shapes are different, hence I used sklearn for Ridge and Lasso regression.

# %%
from sklearn.linear_model import Ridge, Lasso
ridge = Ridge()
ridge.fit(X_train, Y_train)
# Out:
# Ridge()

# %%
Rs(ridge.predict(X_test), Y_test)[0, 0]
RSS(ridge.predict(X_test), Y_test)[0, 0]
# Out:
# 0.10428976039115298

# %%
alphas = [0.0001, 0.001, 0.01, 0.1,1,2,5,7,10,15,20,30,50,100]
r_sqds = []
rss_er = []

for alph in tqdm(alphas):
    ridge = Ridge(alpha=alph)
    ridge.fit(X_train, Y_train)
    Y_pred = ridge.predict(X_test)
    r_sqds.append(Rs(Y_pred, Y_test)[0, 0])
    rss_er.append(RSS(Y_pred, Y_test)[0, 0])
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 14/14 [00:00<00:00, 17.04it/s]

# %%
from operator import itemgetter

min_index, min_rss = min(enumerate(rss_er), key=itemgetter(1)) 
print('Min Alpha, Min RSS = ', alphas[min_index], min_rss)

max_index, max_rs = max(enumerate(r_sqds), key=itemgetter(1)) 
print('Max Alpha, Max R Squared Error = ', alphas[min_index], max_rs)
# Out:
# Min Alpha, Min RSS =  10 0.08101138428687246
# Max Alpha, Max R Squared Error =  10 0.3013347224324413

# %%
fig, ax = plt.subplots(1, 2, figsize=(12, 8))

ax[0].plot(alphas, r_sqds)
ax[0].set_title('R square')
ax[0].plot(alphas[max_index], max_rs, marker='x', color='r', markersize=15)

ax[1].plot(alphas, rss_er)
ax[1].set_title('RSS')
ax[1].plot(alphas[min_index], min_rss, marker='x', color='r', markersize=15)

# %% [markdown]
# The best $\alpha$ value seems to be around 10.

# %%
ls = [-5, -2, -1, -0.1, -0.01, -0.001, -0.0001, 0.0001, 0.001, 0.01, 0.1,1,2,5,7,10,20]
r_sqds = []
rss_er = []

for l in tqdm(ls):
    lasso = Lasso(alpha=l, normalize=True)
    lasso.fit(X_train, Y_train)
    Y_pred = lasso.predict(X_test)
    r_sqds.append(Rs(Y_pred, Y_test)[0, 0])
    rss_er.append(RSS(Y_pred, Y_test)[0, 0])
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 17/17 [00:15<00:00,  1.08it/s]

# %%
from operator import itemgetter

min_index, min_l_rss = min(enumerate(rss_er), key=itemgetter(1)) 
print('Min Lambda, Min RSS = ', ls[min_index], min_l_rss)

max_index, max_l_rs = max(enumerate(r_sqds), key=itemgetter(1)) 
print('Max Lambda, Max R Squared Error = ', ls[min_index], max_l_rs)
# Out:
# Min Lambda, Min RSS =  0.0001 0.07892925868054004
# Max Lambda, Max R Squared Error =  0.0001 0.31929156735595765

# %%
fig, ax = plt.subplots(1, 2, figsize=(12, 8))

ax[0].plot(ls, r_sqds)
ax[0].set_title('R square')
ax[0].plot(alphas[max_index], max_l_rs, marker='x', color='r', markersize=15)

ax[1].plot(ls, rss_er)
ax[1].set_title('RSS')
ax[1].plot(alphas[min_index], min_l_rss, marker='x', color='r', markersize=15)

# %%
dct = {l: r_sq for (l, r_sq) in zip(ls, r_sqds)}
print(dct)
# Out:
# {-5: -5718371259324623.0, -2: -914939398624504.9, -1: -228734848461320.84, -0.1: -2287348269551.378, -0.01: -42575758085.02696, -0.001: -288362791.05500484, -0.0001: -3570142.7643941687, 0.0001: 0.31929156735595765, 0.001: -0.22910004617865676, 0.01: -0.22910004617865676, 0.1: -0.22910004617865676, 1: -0.22910004617865676, 2: -0.22910004617865676, 5: -0.22910004617865676, 7: -0.22910004617865676, 10: -0.22910004617865676, 20: -0.22910004617865676}

# %% [markdown]
# The best value of $\lambda$ seems to be around 7.
